# %%
from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from tqdm import tqdm
from spacy.lang.fr import French
import pandas as pd
import json
import ast
from spacy_langdetect import LanguageDetector
import minibatch
import random
from spacy.util import minibatch, compounding
from spacy.training import Example
import numpy as np

# %%
nlp = French()

# %% [markdown]
# ### Datas

# %%
def read_jsonl(path_json_file):
    with open(path_json_file, 'r') as json_file:
        json_list = list(json_file)
    return json_list

path_json_file = "/Users/remyadda/Desktop/AD/Projets/ALFRED/Datas/Doccano/doccano_skills_outputs_360.jsonl"
DATA = read_jsonl(path_json_file)

# %%
DATA[0]
# Out:
# '{"id": 364, "text": "LOGICIELS MAITRISES: WORD -- EXCEL -- SAGE -- POWERPOINT -- OUTLOOK", "meta": {}, "annotation_approver": null, "labels": [[21, 25, "U-SKILLS"], [29, 34, "U-SKILLS"], [38, 42, "U-SKILLS"], [46, 56, "U-SKILLS"], [60, 67, "U-SKILLS"]]}\n'

# %%
def reformate_datas(TRAIN_DATA):
    """Input: JSON file issu de Doccano
       Output: Datas mis au format du NER"""
    TRAIN = []
    for element in TRAIN_DATA:
        # null pose pb. On le remplace par un mot qqconque
        element = element.replace('null', '"ok"')
        d = eval(element)
        dictOfLabels = {}
        dictOfLabels['entities'] = d['labels']
        listOfTuples = []
        for element in dictOfLabels['entities']:
            element = tuple(element)
            listOfTuples.append(element)
        dictOfLabels['entities'] =  listOfTuples
        TRAIN.append((d['text'], dictOfLabels))
    return TRAIN

# %% [markdown]
# ### Reformate + Train Test Split

# %%
DATA = reformate_datas(DATA)
print(len(DATA))
# Out:
# 361

# %%
TRAIN = DATA[:int(0.8*len(DATA))]
TEST = DATA[int(0.8*len(DATA)):]
print('Len train set : ', len(TRAIN))
print('Len test set : ', len(TEST))
# Out:
# Len train set :  288
# Len test set :  73

# %%
TRAIN
# Out:
# [('LOGICIELS MAITRISES: WORD -- EXCEL -- SAGE -- POWERPOINT -- OUTLOOK',
#   {'entities': [(21, 25, 'U-SKILLS'),
#     (29, 34, 'U-SKILLS'),
#     (38, 42, 'U-SKILLS'),
#     (46, 56, 'U-SKILLS'),
#     (60, 67, 'U-SKILLS')]}),
#  ("COMPETENCES    VV VV VV VV VV V WV    Recevoir, orienter et renseigner les clients    Gerer les agendas, prendre les rendez-vous et traiter les appels telephoniques  Completer et mettre en forme des ecrits professionnels courants    Saisir, actualiser et controler des donnees    Etablir les contrats de travail, realiser les DPAE et programmer les visites medicales  Gerer les contrats, les bons de commande et les notes de frais de l'entreprise  Organiser les deplacements du personnel    Realiser les rapprochements bancaires    Gerer la facturation et le suivi de facturation    Organiser les reunions et les seminaires    Gerer les stocks et les fournitures de l'entreprise    OE Ks1-1 0011 alee lio] eM) Mee Realise y xo mel me (ele aal=lal es",
#   {'entities': []}),
#  ('Competences    Langues  * Anglais : (Langue maternelle)  *  Creole : (Jamaique, Sierra Leone et    TEED    4    Poular : Guinee    o>    SoS    BOC    Susu : Guinee    So    Bot    Mende : Sierra Leone    Informatique / Logiciels    So    Bot    Pack Office  DAX    LV Talent  MY ARDIAN  TETRAWIN  SIMM    AKIO    So    Bot    So    Bot    So    Bot    SS    %    SS    %    SS    %',
#   {'entities': [(26, 33, 'U-ANGLAIS'),
#     (37, 43, 'B-NIVEAU_ANGLAIS'),
#     (44, 54, 'L-NIVEAU_ANGLAIS'),
#     (60, 66, 'U-OTHER_LANGUAGE'),
#     (246, 250, 'B-SKILLS'),
#     (251, 257, 'L-SKILLS'),
#     (259, 262, 'U-SKILLS')]}),
#  ("COMPETENCE    Gestion locative    Analyser une demande de  location    Gerer un planning de vacances  de logements    Proposer l'attrioution de  logements    Etablir un bail immobilier    Realiser un suivi administratif du  recouvrement des loyers et  charges    Recueillir et traiter les  reclamations d'usagers, clients,  residents, ...    Actualiser les informations mises a la  disposition d'un public,    Contreler la conformite de  realisation de fournisseurs, sous-  traitants, prestataires, etc.",
#   {'entities': []}),
#  ('Langues : anglais (niveau  conversationnel), escagnol  (niveau scolaire)',
#   {'entities': [(10, 17, 'U-ANGLAIS'),
#     (19, 25, 'B-NIVEAU_ANGLAIS'),
#     (27, 42, 'L-NIVEAU_ANGLAIS'),
#     (45, 53, 'U-OTHER_LANGUAGE')]}),
#  ('Competences complementaires et linguistiques    Langues :  Anglais/ Espagnol : Capacites professionnelles    Vee Lil emas ope beereaete    Informatique :  Pack office (Word, Power Point)    Excel (tableau croise dynamique, recherche V etc.)  CRM Salesforce',
#   {'entities': [(155, 159, 'B-SKILLS'),
#     (160, 166, 'L-SKILLS'),
#     (168, 172, 'U-SKILLS'),
#     (174, 179, 'B-SKILLS'),
#     (180, 185, 'L-SKILLS'),
#     (190, 195, 'U-SKILLS'),
#     (242, 245, 'U-SKILLS'),
#     (59, 66, 'U-ANGLAIS'),
#     (79, 88, 'B-NIVEAU_ANGLAIS'),
#     (89, 105, 'L-NIVEAU_ANGLAIS'),
#     (246, 256, 'U-SKILLS')]}),
#  ("Informatique    e Mairise du Pack Office (Word, PowerPoint, Excel, OneNote, Outlook)  C/ Utilisation courante d'Internet    C/ Cegid, Axiant, Ciel, Acapulco    Langues    e Arabe bilingue    e Anglais bon niveau    e Allemand niveau scolaire    Competences professionnelles    e Esprit d'equipe, autonomie, organisation, aisance relationnelle",
#   {'entities': [(29, 33, 'B-SKILLS'),
#     (34, 40, 'L-SKILLS'),
#     (42, 46, 'U-SKILLS'),
#     (48, 58, 'U-SKILLS'),
#     (60, 65, 'U-SKILLS'),
#     (67, 74, 'U-SKILLS'),
#     (76, 83, 'U-SKILLS'),
#     (127, 132, 'U-SKILLS'),
#     (134, 140, 'U-SKILLS'),
#     (142, 146, 'U-SKILLS'),
#     (148, 156, 'U-SKILLS'),
#     (173, 178, 'U-OTHER_LANGUAGE'),
#     (201, 204, 'B-NIVEAU_ANGLAIS'),
#     (205, 211, 'L-NIVEAU_ANGLAIS'),
#     (217, 225, 'U-OTHER_LANGUAGE'),
#     (193, 200, 'U-ANGLAIS')]}),
#  ('Competences informatiques    Maitrise du pack office    Logiciel Abydos    Logiciel SAGE facturation et devis  Logiciel de comptabilite ANAEL  Logiciel ZEUS, ARMADO et COFFREO  Logiciel de gestion EBP    vA    , ae ene | ee ae',
#   {'entities': [(41, 45, 'B-SKILLS'),
#     (46, 52, 'L-SKILLS'),
#     (65, 71, 'U-SKILLS'),
#     (84, 88, 'U-SKILLS'),
#     (136, 141, 'U-SKILLS'),
#     (152, 156, 'U-SKILLS'),
#     (158, 164, 'U-SKILLS'),
#     (168, 175, 'U-SKILLS'),
#     (177, 185, 'B-SKILLS'),
#     (186, 188, 'I-SKILLS'),
#     (189, 196, 'I-SKILLS'),
#     (197, 200, 'L-SKILLS')]}),
#  ('Competences linguistiques    Anglais : niveau A2    mA CILMM Cesta',
#   {'entities': [(39, 45, 'B-NIVEAU_ANGLAIS'),
#     (46, 48, 'L-NIVEAU_ANGLAIS'),
#     (29, 36, 'U-ANGLAIS')]}),
#  ('Office Manager    Prospection commerciale  Relations avec les partenaires  B2B et B2C    Excellent sens relationnel  Autonomie et capacitee a  prendre des responsabilites et  decisions    Charge de gestion et suivi  portefeuille de clients societes    Italien : Langue maternelle  Frangais : Bilingue  Anglais : Courant  Espagnol : Courant',
#   {'entities': [(252, 259, 'U-OTHER_LANGUAGE'),
#     (302, 309, 'U-ANGLAIS'),
#     (312, 319, 'U-NIVEAU_ANGLAIS'),
#     (321, 329, 'U-OTHER_LANGUAGE')]}),
#  ("re    la a eee ate _  ca) ln i ho [K { j | 4  0 ee Ae 2a    )    e    POLYVALENTE  OUVERTE D'ESPRIT  BONNE COMMUNICANTE  ESPRIT D'EQUIPE  ORGANISEE    f ee oe on a) ai ed  NN ee Ke PEW eA) i' ff mn oS    PACK OFFICE    SALES FORCE  SLACK    HOOTSUITE  A.PREMIERE / IMOVIE    GESTION DES PRIORITES  TRAITEMENT DE DOSSIERS  ADMINISTRATIFS    GESTION DE PROJET    LOGISTIQUE / ORGANISATION  D'EVENEMENTS    OPTIMISATION DE L'EXPERIENCE  CLIENT    VEILLE / SUIVI DES TENDANCES DU  NSS Ol al =    Fy Papa acon eel aa  AN C10 lens:    ANGLAIS - Bilingue C2  ALLEMAND - Intermediaire B2  ESPAGNOL - Debutant A2",
#   {'entities': [(204, 208, 'B-SKILLS'),
#     (209, 215, 'L-SKILLS'),
#     (219, 224, 'B-SKILLS'),
#     (225, 230, 'L-SKILLS'),
#     (232, 237, 'U-SKILLS'),
#     (529, 536, 'U-ANGLAIS'),
#     (539, 547, 'U-NIVEAU_ANGLAIS'),
#     (552, 560, 'U-OTHER_LANGUAGE'),
#     (581, 589, 'U-OTHER_LANGUAGE')]}),
#  ('COMPETENCE    Langues EURtrangeres :    Anglais (Courant - TOEIC :  800)  Espagnol (Notions)    Informatique :    Maitrise dans ses fonctions  avanceees du Pack Office  (Word, Excel, Power Point,  Publisher)    Logiciels :  AS400',
#   {'entities': [(40, 47, 'U-ANGLAIS'),
#     (49, 56, 'U-NIVEAU_ANGLAIS'),
#     (74, 82, 'U-OTHER_LANGUAGE'),
#     (156, 160, 'B-SKILLS'),
#     (161, 167, 'L-SKILLS'),
#     (170, 174, 'U-SKILLS'),
#     (176, 181, 'U-SKILLS'),
#     (183, 188, 'B-SKILLS'),
#     (189, 194, 'L-SKILLS'),
#     (197, 206, 'U-SKILLS'),
#     (224, 229, 'U-SKILLS')]}),
#  ('Langues francais, anglais, espagnol, portugais, allemand, hebreu -- Berlin en 2011-2012',
#   {'entities': [(18, 25, 'U-ANGLAIS'),
#     (27, 35, 'U-OTHER_LANGUAGE'),
#     (37, 46, 'U-OTHER_LANGUAGE'),
#     (48, 56, 'U-OTHER_LANGUAGE'),
#     (58, 64, 'U-OTHER_LANGUAGE')]}),
#  ('Competences  professionnelles    e Movie (MAC)    e Excel, Word, Power Point    e Maitrise des reseaux sociaux    e Redaction de contenus (compte  rendu de reunion...)    e Indesign    Competences  personnelles    e Organisee    e Reactive    e Autonome    e Aisance orale et relationelle',
#   {'entities': [(52, 57, 'U-SKILLS'),
#     (59, 63, 'U-SKILLS'),
#     (65, 70, 'B-SKILLS'),
#     (71, 76, 'L-SKILLS')]}),
#  ('LANGUES    ANGLAIS ESPAGNOL  Niveau B1 Notions',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (19, 27, 'U-OTHER_LANGUAGE'),
#     (29, 35, 'B-NIVEAU_ANGLAIS'),
#     (36, 38, 'L-NIVEAU_ANGLAIS')]}),
#  ('COMPETENCES INFORMATIQUES    - Environnements : Windows Seven, TCP/IP, DNS, DHCP, LAN, WAN.  ae yuyu : Pack Office, SMS 1.2, Ghost, Exchange, Lotus Notes, Outlook, Viritas.  - Mateeriels : Hub, Switch CATALYS, Routeur CISCO, Imprimante, scanner, Palme pilot,    - Outils de supervision : HP Openview, Control M, Patrol V3, Univers$, Chekpoint, Cisco View, TNG.',
#   {'entities': [(71, 74, 'U-SKILLS'),
#     (76, 80, 'U-SKILLS'),
#     (82, 85, 'U-SKILLS'),
#     (87, 90, 'U-SKILLS'),
#     (103, 107, 'B-SKILLS'),
#     (108, 114, 'L-SKILLS'),
#     (116, 119, 'U-SKILLS'),
#     (125, 130, 'U-SKILLS'),
#     (132, 140, 'U-SKILLS'),
#     (142, 147, 'U-SKILLS'),
#     (148, 153, 'U-SKILLS'),
#     (155, 162, 'U-SKILLS'),
#     (164, 171, 'U-SKILLS'),
#     (189, 192, 'U-SKILLS'),
#     (194, 200, 'U-SKILLS'),
#     (201, 208, 'U-SKILLS'),
#     (344, 349, 'U-SKILLS')]}),
#  ('COMPETENCES    PROFESSIONNELLES :    = Hierarchisation des priorites    =" Optimisation des process d\'expertises  = Analyse des donnees    # Utilisation des outils CRM  PERSONNELLES :    =" Garant du respect des regles    ae el alaael- ik    =" Capacite d\'adaptation    = Aisance relationnelle  INFORMATIQUES :    = Windows 10    = Suite Office 2010 (Word, Excel, Powerpoint)  sy AN',
#   {'entities': [(164, 167, 'U-SKILLS'),
#     (351, 355, 'U-SKILLS'),
#     (357, 362, 'U-SKILLS'),
#     (364, 374, 'U-SKILLS')]}),
#  ('LANGUES    Francais : Langue maternelle  Anglais : Courant  Espagnol : Bon',
#   {'entities': [(41, 48, 'U-ANGLAIS'),
#     (51, 58, 'U-NIVEAU_ANGLAIS'),
#     (60, 68, 'U-OTHER_LANGUAGE')]}),
#  ('LANGUES ET COMPETENCES    Anglais: Professionnel (770 points au TOEIC)  Logiciel: Maitrise complete du pack Office (Excel, Word, Power Point)  OEnologie: Dipl6me WSET 2 et preparation du WSET 3',
#   {'entities': [(26, 33, 'U-ANGLAIS'),
#     (35, 48, 'U-NIVEAU_ANGLAIS'),
#     (103, 107, 'B-SKILLS'),
#     (108, 114, 'L-SKILLS'),
#     (116, 121, 'U-SKILLS'),
#     (123, 127, 'U-SKILLS'),
#     (129, 134, 'B-SKILLS'),
#     (135, 140, 'L-SKILLS')]}),
#  ('COMPETENCES    Vente  xk* x    Teamwork  5 a ae ae    Adaptabilite  > ae aes    Problem-Solver',
#   {'entities': []}),
#  ('Anglais: Bilingue Cl  (TOEIC/TOEFL/FCE)  > ab ae ae    Espagnol: B2    a ae aed  Chinois: Debutant  *    Pack Office: certifie MOS  keen    CRM: Hubspot/Salesforces  an ae    Photoshop/Wordpress:  ae',
#   {'entities': [(0, 7, 'U-ANGLAIS'),
#     (9, 17, 'U-NIVEAU_ANGLAIS'),
#     (55, 63, 'U-OTHER_LANGUAGE'),
#     (81, 88, 'U-OTHER_LANGUAGE'),
#     (105, 109, 'B-SKILLS'),
#     (110, 116, 'L-SKILLS'),
#     (140, 143, 'U-SKILLS'),
#     (175, 184, 'U-SKILLS'),
#     (185, 194, 'U-SKILLS')]}),
#  ('COMPETENCES    =>> Administratif    = Comptabilite / Facturation    = Communication / Marketing  >> Evenementiel / Logistique    >> Services generaux / Securite',
#   {'entities': []}),
#  ('INFORMATIQUE    >> Univers PC et MAC    = Pack Office (Word, Excel, PWP)  = Outlook, Lotus Note, GED    = CRM, e-mailing, Mailchip    = Adobe, Indesign, WordPress    >> Reseaux sociaux, Internet',
#   {'entities': [(42, 46, 'B-SKILLS'),
#     (47, 53, 'L-SKILLS'),
#     (55, 59, 'U-SKILLS'),
#     (61, 66, 'U-SKILLS'),
#     (68, 71, 'U-SKILLS'),
#     (85, 90, 'U-SKILLS'),
#     (91, 95, 'U-SKILLS'),
#     (97, 100, 'U-SKILLS'),
#     (76, 83, 'U-SKILLS'),
#     (106, 109, 'U-SKILLS'),
#     (136, 141, 'U-SKILLS'),
#     (143, 151, 'U-SKILLS'),
#     (153, 162, 'U-SKILLS'),
#     (169, 176, 'B-SKILLS'),
#     (177, 184, 'L-SKILLS')]}),
#  ('LANGUE    >> ANGLAIS (intermediaire)',
#   {'entities': [(13, 20, 'U-ANGLAIS'), (22, 35, 'U-NIVEAU_ANGLAIS')]}),
#  ('SOFT SKILLS    = Polyvalente / Proactive  = Endurante / Investie    >> Aptitude a anticiper    >> Resistante au stress    >> Discretion / Confiance  =>> Bonne humeur',
#   {'entities': []}),
#  ("DOMAINES D'INTERVENTION    % Assistanat polyvalent    = Organisation/logistique :  Reunion, CR, AG et CA,  deplacements...    Sy Xela al isiie-ll ae  Base de donnees, reporting  financier, petite comptabilite    = Gestion Services Generaux :  Etude et traitement de dossiers  (assurances, reclamations,  contentieux, intendance).  Relations prestataires    = Gestion portefeuille commercial  Fidelisation, suivi, contentieux",
#   {'entities': []}),
#  ('% R.H. Gestion du Personnel    = Recrutement :    Fiches de poste, gestion des  prestataires, entretiens d\'embauche,  redaction contrat de travail : CDI, CDD,  contrat d\'alternance, Extra. Procedure de  sortie. Onboarding    "Gestion administrative RH :    Visites medicales, DUE, tenue du  registre du personnel, organigrammes,  reporting, tickets restaurant...  Preparation des elements de la paye    = Formation :  Collecte et analyse des besoins, mise en  place des formations',
#   {'entities': []}),
#  ("% Autres competences :    % Logiciels :  > Office 360, Visio, maitrise d'Excel  => Logiciels specialises RH",
#   {'entities': [(43, 49, 'B-SKILLS'),
#     (50, 53, 'L-SKILLS'),
#     (55, 60, 'U-SKILLS'),
#     (71, 78, 'U-SKILLS'),
#     (83, 92, 'B-SKILLS'),
#     (93, 104, 'I-SKILLS'),
#     (105, 107, 'L-SKILLS')]}),
#  ('% Langue etrangere :  Anglais : niveau avance  Toeic 658 sur 980, Oct/2020',
#   {'entities': [(22, 29, 'U-ANGLAIS'),
#     (32, 38, 'B-NIVEAU_ANGLAIS'),
#     (39, 45, 'L-NIVEAU_ANGLAIS')]}),
#  ("COMPETENCES    > Accueillir des usagers, les diriger,  noter les messages et planifier  les rendez-vous    > Tri, distribution,  affranchissement,  enregistrement du courrier et  gestion des messages  electroniques    > Gestion du standard  telephonique    > Rediger et mettre en forme les  documents, les faire suivre    > Classement, archivage  numerique    > Utilisation d'outils bureautique    > Maitrise de WORD, EXCEL    > Verifier l'etat des stocks, evaluer  les besoins en  approvisionnement et definir les  commandes a passer    > Actualisation des donnees de  suivi sur PRONOTE (notes,    absences, retard, vie scolaire)    > Aide ala vie scolaire",
#   {'entities': [(412, 416, 'U-SKILLS'), (418, 423, 'U-SKILLS')]}),
#  ("Competences    Connaissance des normes juridique  Sens de l'organisation    Maitrise de I'outil informatique  Sens du relationnel    Analyse de documentation juridique    O    Langues  Anglais  Correct    Espagnol  Bon",
#   {'entities': [(185, 192, 'U-ANGLAIS'),
#     (194, 201, 'U-NIVEAU_ANGLAIS'),
#     (205, 213, 'U-OTHER_LANGUAGE')]}),
#  ("Commerciale :    O00 0 0    Negociation commerciale  Sourcing    Suivi d''expeditions  Gestion des litiges    Analyse de donnees    Langues :    oO    O  O  O    Anglais : Avance (Toeic  Listening & Reading 930/990)  Mandarin : Novice    Espagnol : Novice    Tamoul : Courant    Informatique :    6)    Pack Office (Excel : TCD,  Recherche V...)    Logiciels de montage video  et photo",
#   {'entities': [(162, 169, 'U-ANGLAIS'),
#     (172, 178, 'U-NIVEAU_ANGLAIS'),
#     (217, 225, 'U-OTHER_LANGUAGE'),
#     (238, 246, 'U-OTHER_LANGUAGE'),
#     (303, 307, 'B-SKILLS'),
#     (308, 314, 'L-SKILLS'),
#     (316, 321, 'U-SKILLS'),
#     (349, 358, 'B-SKILLS'),
#     (359, 361, 'I-SKILLS'),
#     (362, 369, 'I-SKILLS'),
#     (370, 375, 'I-SKILLS'),
#     (377, 379, 'I-SKILLS'),
#     (380, 385, 'L-SKILLS')]}),
#  ('80) eae)    INFORMATIQUES  MS Office    Word    Excel    Powerpoint    Access',
#   {'entities': [(40, 44, 'U-SKILLS'),
#     (48, 53, 'U-SKILLS'),
#     (57, 67, 'U-SKILLS'),
#     (71, 77, 'U-SKILLS')]}),
#  ('LANGUES    Anglais : Intermediaire  Espagnol : Bilingue  Portugais : Bilingue',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 34, 'U-NIVEAU_ANGLAIS'),
#     (36, 44, 'U-OTHER_LANGUAGE'),
#     (57, 66, 'U-OTHER_LANGUAGE')]}),
#  ('Outils informatiques    Pack Office  - Oracle  * Ariba',
#   {'entities': [(24, 28, 'B-SKILLS'),
#     (29, 35, 'L-SKILLS'),
#     (39, 45, 'U-SKILLS'),
#     (49, 54, 'U-SKILLS')]}),
#  ("Competences    - Coordination de l'activite des equipes  - Force de proposition    - Gestion d'evenements    - Redaction de cahier des charges    - Conduite de projets    - Leadership    - Gestion administrative du personnel",
#   {'entities': []}),
#  ('Mes competences    Logiciel: Pamo, @ @ @  Sage Batigest,  Ora,    Traitementde @ @ @    iCs).4s    TableurExcl @ @ @  Power Point (c) (c) @    LANGUES    Espagnol. couramment    Anglais=< Operationnel  commercial',
#   {'entities': [(29, 33, 'U-SKILLS'),
#     (42, 46, 'U-SKILLS'),
#     (47, 55, 'U-SKILLS'),
#     (58, 61, 'U-SKILLS'),
#     (154, 162, 'U-OTHER_LANGUAGE'),
#     (178, 185, 'U-ANGLAIS'),
#     (188, 200, 'U-NIVEAU_ANGLAIS')]}),
#  ('Informatique    Windows: Skype Entreprise Office 365  Windows Client :    7|8.1|10    Windows Serveur :    2008 R2 | 2012 R2 | 2016    Apple: Mac OS X Mountain Lion, Snow  Leopard , Leopard, High Sierra , El  Capitan, Mavericks , Yosemite.    Protocoles: RIP, OSPF, FTP, SSL,  TELNET, TCP/IP, HSRP, DHCP    Securite Bitlockers, ACL, VPN , Firewall  Antivirus : Kaspersky Sophos Endpoint  McAfee .    Supervision : Centreon    Prise de Main a Distance: TeamViewer,  Panda, Ultra VNC    Virtualisation : VMware : Workstation  ESXi .    Oracle :VirtualBOX .    Microsoft HyperV    Langues    Anglais Niveau technique    Francais Langue Maternelle',
#   {'entities': [(25, 30, 'U-SKILLS'),
#     (54, 61, 'U-SKILLS'),
#     (172, 179, 'U-SKILLS'),
#     (534, 540, 'U-SKILLS'),
#     (524, 528, 'U-SKILLS'),
#     (511, 522, 'U-SKILLS'),
#     (465, 470, 'U-SKILLS'),
#     (316, 326, 'U-SKILLS'),
#     (328, 331, 'U-SKILLS'),
#     (333, 336, 'U-SKILLS'),
#     (339, 347, 'U-SKILLS'),
#     (371, 377, 'B-SKILLS'),
#     (589, 596, 'U-ANGLAIS'),
#     (597, 603, 'B-NIVEAU_ANGLAIS'),
#     (604, 613, 'L-NIVEAU_ANGLAIS'),
#     (230, 238, 'U-SKILLS'),
#     (218, 227, 'U-SKILLS'),
#     (452, 462, 'U-SKILLS'),
#     (243, 253, 'U-SKILLS')]}),
#  ('Sas    Programmation  HTML5 << PHP7 << CSS3    MySQL e Linux e Git    C e Latex',
#   {'entities': [(22, 27, 'U-SKILLS'),
#     (31, 35, 'U-SKILLS'),
#     (39, 43, 'U-SKILLS'),
#     (47, 52, 'U-SKILLS'),
#     (55, 60, 'U-SKILLS'),
#     (63, 66, 'U-SKILLS'),
#     (74, 79, 'U-SKILLS')]}),
#  ('Langues    Anglais - Niveau B2/C1',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 27, 'B-NIVEAU_ANGLAIS'),
#     (28, 33, 'L-NIVEAU_ANGLAIS')]}),
#  ("COMPETENCES    e Capacite a s'organiser, prioriser les  es (eanl-ts    e Capacite d'adaptation    e Travail en equipe    e Qutils numeriques    e Bonne communication orale et ecrite    e Autonomie    e Ressources Humaines    e Administration",
#   {'entities': []}),
#  ("PROFIL    eae DDT eked anictewr- NA sLOm INT -NLaLO)    e Anglais courant : B2 - C1    e Experiences dans les RH et  'administration    e Competences comportementales",
#   {'entities': [(58, 65, 'U-ANGLAIS'), (66, 73, 'U-NIVEAU_ANGLAIS')]}),
#  ('Competences    Anglais  Espagnol    Pack Office confirme  Photoshop  Indesign',
#   {'entities': [(15, 22, 'U-ANGLAIS'),
#     (24, 32, 'U-OTHER_LANGUAGE'),
#     (36, 40, 'B-SKILLS'),
#     (41, 47, 'L-SKILLS'),
#     (58, 67, 'U-SKILLS'),
#     (69, 77, 'U-SKILLS')]}),
#  ("Accueillir (accueil physique et telephonique) et informer le public    Gestion du planning (prise de rendez-vous, reservation et preparation des salles et organisation de reunions)    Redaction et saisie de documents informatiques    Participation aux reunions d'information et de service    Contribuer a la demarche de projet    Participation a la demarche qualite    Animer et travailler en equipe    Traitement de la demande et du besoin de l'usager en lien avec l'offre de services    Mise en ceuvre d'elements adaptes (documents, outils...) aux besoins d'une structure    Gestion et organisation des deplacements professionnels (reservations de vols, trains et hotels, location de vehicule...)  Participation a la gestion comptable des activites de la structure et gestion et validation de notes de frais    Assurer les fonctions de secretariat classique (courrier, mailing, planning)    Assurer le secretariat technique lie a l'activite medicale : Gestion du planning des specialistes (prise de rendez-vous, redaction  de compte-rendu, programmation et organisation d'hospitalisations, d'examens medicaux et d'interventions chirurgicales) et  du suivi administratif des dossiers patients (saisie d'informations generales, mise a jour des fiches medicales)    Assurer le secretariat technique lie a l'activite comptable : Gestion des notes de frais et des dossiers lies a la periode fiscale.",
#   {'entities': []}),
#  ('= Competences Informatiques et Linguistiques    Informatique : Microsoft Word, Excel et PowerPoint  Langues : Anglais (Pratique courante) et Espagnol (Niveau scolaire)',
#   {'entities': [(63, 72, 'U-SKILLS'),
#     (73, 77, 'U-SKILLS'),
#     (79, 84, 'U-SKILLS'),
#     (88, 98, 'U-SKILLS'),
#     (110, 117, 'U-ANGLAIS'),
#     (119, 127, 'B-NIVEAU_ANGLAIS'),
#     (128, 136, 'L-NIVEAU_ANGLAIS'),
#     (141, 149, 'U-OTHER_LANGUAGE')]}),
#  ('Informatique :    Connaissance du Pack office,  ICS ,    MAGI THETRAWIN ,PERICLES',
#   {'entities': [(34, 38, 'B-SKILLS'),
#     (39, 45, 'L-SKILLS'),
#     (48, 51, 'U-SKILLS'),
#     (57, 61, 'B-SKILLS'),
#     (62, 71, 'L-SKILLS'),
#     (73, 81, 'U-SKILLS')]}),
#  ('Langues :  Anglais : courant    Espagnol : notion',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 28, 'U-NIVEAU_ANGLAIS'),
#     (32, 40, 'U-OTHER_LANGUAGE')]}),
#  ('Competences  Negociation  Approvisionnement  Retail / Wholesale    Analyse de donnees',
#   {'entities': []}),
#  ('Informatique    JOOR  Excel (Recherche V, TCD)    Pack office',
#   {'entities': [(16, 20, 'U-SKILLS'),
#     (22, 27, 'U-SKILLS'),
#     (50, 54, 'B-SKILLS'),
#     (55, 61, 'L-SKILLS')]}),
#  ('Langues  Anglais    Operationnel    Espagnol    Scolaire    Chinois    Notions',
#   {'entities': [(9, 16, 'U-ANGLAIS'),
#     (20, 32, 'U-NIVEAU_ANGLAIS'),
#     (36, 44, 'U-OTHER_LANGUAGE'),
#     (60, 67, 'U-OTHER_LANGUAGE')]}),
#  ("Sens des responsabilites, priorites et de  l'organisation - Prise d'initiative adaptabilite &  esprit d'equi    Logiciels Word, Excel (intermediaire) Power  Point (intermediaire), messagerie Groupwise (cc  mail), Outlook express, Batappli, EBP compta, AS  400, Navision, Talentia, Internet, Photoshop CS4  (notions)    Discrete, rigoureuse, dynamique, autonome,  autodidacte, polyvalente, tres bon relationnel    Nar le Notions  Portugais : Langue maternelle",
#   {'entities': [(122, 126, 'U-SKILLS'),
#     (128, 133, 'U-SKILLS'),
#     (150, 155, 'B-SKILLS'),
#     (157, 162, 'L-SKILLS'),
#     (191, 200, 'U-SKILLS'),
#     (213, 220, 'U-SKILLS'),
#     (230, 238, 'U-SKILLS'),
#     (240, 243, 'B-SKILLS'),
#     (244, 250, 'L-SKILLS'),
#     (252, 254, 'B-SKILLS'),
#     (256, 259, 'L-SKILLS'),
#     (261, 269, 'U-SKILLS'),
#     (271, 279, 'U-SKILLS'),
#     (291, 300, 'U-SKILLS'),
#     (429, 438, 'U-OTHER_LANGUAGE')]}),
#  ('INFORMATIQUE  Microsoft Office 365         Sharepoint    Adobe Illustrateur         Google Analytics         Cegid',
#   {'entities': [(14, 23, 'U-SKILLS'),
#     (43, 53, 'U-SKILLS'),
#     (57, 62, 'U-SKILLS'),
#     (84, 90, 'B-SKILLS'),
#     (91, 100, 'L-SKILLS'),
#     (109, 114, 'U-SKILLS')]}),
#  ('LANGUES  Francais  Courant  ANTE  Courant  URL  Langue maternelle',
#   {'entities': []}),
#  ('COMPETENCES         Informatique    e Excel (tableau de bord, tableau de suivi,  tableau croise dynamique) - Outlook  Express - SAGE - SAP: Avancee    Langues    e Anglais: Professionnel    e Francais: Bilingue    e Vietnamien: Langue Maternelle  e Chinois: Debutant',
#   {'entities': [(38, 43, 'U-SKILLS'),
#     (109, 116, 'U-SKILLS'),
#     (128, 132, 'U-SKILLS'),
#     (135, 138, 'U-SKILLS'),
#     (164, 171, 'U-ANGLAIS'),
#     (173, 186, 'U-NIVEAU_ANGLAIS'),
#     (216, 226, 'U-OTHER_LANGUAGE'),
#     (249, 256, 'U-OTHER_LANGUAGE')]}),
#  ('LOGICIELS    Suite Adobe @@ee@0@0  Office 365 ee0e00  Wordpress @@@ood  FinalCutProX @@@Q@OO',
#   {'entities': [(19, 24, 'U-SKILLS'),
#     (35, 41, 'B-SKILLS'),
#     (42, 45, 'L-SKILLS'),
#     (54, 63, 'U-SKILLS'),
#     (72, 84, 'U-SKILLS')]}),
#  ('LANGUES    Frangais (langue native)  Anglais (avance - usage courant)  Espagnol (avance - usage courant)',
#   {'entities': [(37, 44, 'U-ANGLAIS'),
#     (46, 52, 'U-NIVEAU_ANGLAIS'),
#     (71, 79, 'U-OTHER_LANGUAGE')]}),
#  ('COMPETENCES    e Chargee de clientele,  Conseillere vente    LANGUES    Anglais    Teale    Allemand    Notions elementaires    Espagnole    Notions elaementaires',
#   {'entities': [(72, 79, 'U-ANGLAIS'),
#     (92, 100, 'U-OTHER_LANGUAGE'),
#     (128, 137, 'U-OTHER_LANGUAGE')]}),
#  ('COMPETENCES LINGUISTIQUES  ET INFORMATIQUES    - Langue 1: Anglais, assez bon niveau  - Langue 2 : Espagnol, excellent niveau  - Langue 3: Portugais, bilingue    Intormatique : Bonne maitrise des outils  bureautiques Microsoft Office    Bonne maitrise des logiciels immobiliers :  - GESTEAM    SATA Olea=ah    Salers    eels',
#   {'entities': [(59, 66, 'U-ANGLAIS'),
#     (68, 73, 'B-NIVEAU_ANGLAIS'),
#     (74, 77, 'I-NIVEAU_ANGLAIS'),
#     (78, 84, 'L-NIVEAU_ANGLAIS'),
#     (99, 107, 'U-OTHER_LANGUAGE'),
#     (139, 148, 'U-OTHER_LANGUAGE'),
#     (217, 226, 'B-SKILLS'),
#     (227, 233, 'L-SKILLS'),
#     (283, 290, 'U-SKILLS'),
#     (294, 298, 'U-SKILLS')]}),
#  ("> Autonome, Grande capacite d'adaptation, Rigueur,  ai X-t-18 1 R-PeltiM- Mi T-(e- Me gr] e) =)",
#   {'entities': []}),
#  ('COMPETENCES CLEES    - Key user ( logiciel, qualite...)  Organisation, planification, relationnel  - Gestion plannings complexes  - RH:  Assurer la gestion administrative des  dossiers des salaries  Proposer, deployer et assurer la  diffusion des procedures RH  Elaborer et actualiser les tableaux de  bord RH  Assurer une veille juridique et sociale  Collecter les elements variables de  paie et verifier leur prise en compte  -Pack Office',
#   {'entities': [(429, 433, 'B-SKILLS'), (434, 440, 'L-SKILLS')]}),
#  ('LANGUES - INFORMATIQUE    Notion  Intermediaire  Bon niveau  Bon niveau',
#   {'entities': []}),
#  ('COMPETENCES PROFESSIONNELLES', {'entities': []}),
#  ('LANGUES  Anglais : Debutant    COMPETENCES    Outils bureautiques : Pack  Office, Sage',
#   {'entities': [(9, 16, 'U-ANGLAIS'),
#     (19, 27, 'U-NIVEAU_ANGLAIS'),
#     (68, 72, 'B-SKILLS'),
#     (74, 80, 'L-SKILLS'),
#     (82, 86, 'U-SKILLS')]}),
#  ("SO) SES Nes    Polyvalente et autonome    Respect des procedures d'organisation de travail  Travail en equipe    Reel sens commercial et de l'accueil    Aisance relationnelle    Methodique    Disponible, rigoureuse, implique",
#   {'entities': []}),
#  ("INFORMATIQUE - LOGICIELS    Microsoft Office, Power Point    Maitrise d'outils lies a internet (messagerie,  moteur de recherche...)    Logiciel GTB (Gestion Technique du Batiment)  Logiciel GMAO (Gestion de Maintenance  Assiste par Ordinateur)    Logiciel Progib (facturation, devis...)    DUE (Declaration Unique d'Employe)",
#   {'entities': [(28, 37, 'B-SKILLS'),
#     (38, 44, 'L-SKILLS'),
#     (46, 51, 'B-SKILLS'),
#     (52, 57, 'L-SKILLS'),
#     (136, 144, 'B-SKILLS'),
#     (145, 148, 'I-SKILLS'),
#     (150, 157, 'I-SKILLS'),
#     (158, 167, 'I-SKILLS'),
#     (168, 170, 'I-SKILLS'),
#     (171, 179, 'L-SKILLS'),
#     (182, 190, 'B-SKILLS'),
#     (191, 195, 'I-SKILLS'),
#     (197, 204, 'I-SKILLS'),
#     (205, 207, 'I-SKILLS'),
#     (208, 219, 'I-SKILLS'),
#     (221, 228, 'I-SKILLS'),
#     (229, 232, 'I-SKILLS'),
#     (233, 243, 'I-SKILLS'),
#     (248, 256, 'B-SKILLS'),
#     (257, 263, 'L-SKILLS'),
#     (291, 294, 'B-SKILLS'),
#     (296, 307, 'I-SKILLS'),
#     (308, 314, 'I-SKILLS'),
#     (315, 324, 'L-SKILLS')]}),
#  ('INFORMATIQUE  a SAP    Pack Office Photoshop SAP Logiciel WordPress',
#   {'entities': [(16, 19, 'U-SKILLS'),
#     (23, 27, 'B-SKILLS'),
#     (28, 34, 'L-SKILLS'),
#     (35, 44, 'U-SKILLS'),
#     (45, 48, 'U-SKILLS'),
#     (58, 67, 'U-SKILLS')]}),
#  ('LANGUES    C/ Francais (langue maternelle) C/ Anglais (C2)',
#   {'entities': [(46, 53, 'U-ANGLAIS'), (55, 57, 'U-NIVEAU_ANGLAIS')]}),
#  ('LOGICIELS    > Pack office : Word, Excel, PowerPoint, Outlook    >>> Sharepoint, SAP    > Logiciels metiers: | EDF: FIDAA- PEI (Acces centrales nucleaires et autorisations Prefectorales), Dauphin, Docusign, Trhips,  Power BI (fiche de banque)  SANOFI : Cleantrace 2.6 - 2.8 (base pharmacovigilance)  SOCIETE GENERALE : Gest Dab (gestion individuelle de la rentabilite des distributeurs de billets)',
#   {'entities': [(15, 19, 'B-SKILLS'),
#     (20, 26, 'L-SKILLS'),
#     (29, 33, 'U-SKILLS'),
#     (35, 40, 'U-SKILLS'),
#     (42, 52, 'U-SKILLS'),
#     (54, 61, 'U-SKILLS'),
#     (69, 79, 'U-SKILLS'),
#     (81, 84, 'U-SKILLS'),
#     (111, 114, 'U-SKILLS'),
#     (116, 121, 'U-SKILLS'),
#     (123, 126, 'U-SKILLS'),
#     (188, 195, 'U-SKILLS'),
#     (197, 205, 'U-SKILLS'),
#     (207, 213, 'U-SKILLS'),
#     (216, 221, 'B-SKILLS'),
#     (222, 224, 'L-SKILLS')]}),
#  ('COMPETENCES    Ls    Pack Office (Excel  avance)    SAP (FI, CO)    PGI CEGID (gestion  commerciale,  comptabilite,  immobilisations et paie)    Anglais : intermediaire  Espagnol : notions  scolaires',
#   {'entities': [(21, 25, 'B-SKILLS'),
#     (26, 32, 'L-SKILLS'),
#     (34, 39, 'U-SKILLS'),
#     (52, 55, 'U-SKILLS'),
#     (68, 71, 'U-SKILLS'),
#     (72, 77, 'U-SKILLS'),
#     (170, 178, 'U-OTHER_LANGUAGE'),
#     (145, 152, 'U-ANGLAIS'),
#     (155, 168, 'U-NIVEAU_ANGLAIS')]}),
#  ('INFORMATIQUE    Utilisation des logiciels SACE et SAP  Pack office  Canva    QUALITES    o Autonomie    o Polyvalence    o Discretion    o Bonne presentation  o Gestion courante',
#   {'entities': [(42, 46, 'U-SKILLS'),
#     (50, 53, 'U-SKILLS'),
#     (55, 59, 'B-SKILLS'),
#     (60, 66, 'L-SKILLS'),
#     (68, 73, 'U-SKILLS')]}),
#  ('INFORMATIQUE    Pack Office, Outlook, Dalloz,  Navis et LexisNexis  LANGUES    Anglais courant  Francais  Malgache',
#   {'entities': [(16, 20, 'B-SKILLS'),
#     (21, 27, 'L-SKILLS'),
#     (29, 36, 'U-SKILLS'),
#     (38, 44, 'U-SKILLS'),
#     (47, 52, 'U-SKILLS'),
#     (56, 66, 'U-SKILLS'),
#     (79, 86, 'U-ANGLAIS'),
#     (87, 94, 'U-NIVEAU_ANGLAIS'),
#     (106, 114, 'U-OTHER_LANGUAGE')]}),
#  ("LANGUES  Anglais Niveau B2    | worked for 10 months in Manchester  (UK), daily in contact with customers    COMPETENCES    Soft Skills  Travail d'equipe Capacite d'adaptation  Gestion du stress Autonomie    Aisance relationnelle    Hard Skills  Vente et negociation Business development  Force de proposition Vision strategique    Capacite analytique",
#   {'entities': [(9, 16, 'U-ANGLAIS'),
#     (17, 23, 'B-NIVEAU_ANGLAIS'),
#     (24, 26, 'L-NIVEAU_ANGLAIS')]}),
#  ("Competences    Connaissance d'outils    de donnees Cegid quadra, Fonctions de Bloomberg , Gretl ,  AEA (=) aot)    Competences en  ele Comptabilite Client    Culture numerique    appliquee a Elaboration d'un modele de pricing des titres financiers  l'economie",
#   {'entities': [(51, 56, 'U-SKILLS'),
#     (57, 63, 'U-SKILLS'),
#     (90, 95, 'U-SKILLS')]}),
#  ("CI Informatique    Cegid Quadra    Lettrage de comptes , fiscalite, paie,  gestion interne    Bloomberg Market Concept    Modele de pricing d'un actif financier    VBA    A Langues    Anglais  Award certificate USA EMBASSY    Francais    Arabe",
#   {'entities': [(19, 24, 'U-SKILLS'),
#     (25, 31, 'U-SKILLS'),
#     (94, 103, 'U-SKILLS'),
#     (164, 167, 'U-SKILLS'),
#     (184, 191, 'U-ANGLAIS'),
#     (193, 198, 'B-NIVEAU_ANGLAIS'),
#     (199, 210, 'I-NIVEAU_ANGLAIS'),
#     (211, 214, 'I-NIVEAU_ANGLAIS'),
#     (215, 222, 'L-NIVEAU_ANGLAIS'),
#     (238, 243, 'U-OTHER_LANGUAGE')]}),
#  ("Competences    Connaissance des normes juridique  Sens de l'organisation    Maitrise de I'outil informatique  Sens du relationnel    Analyse de documentation juridique    O    Langues  Anglais  Correct    Espagnol  Bon",
#   {'entities': [(185, 192, 'U-ANGLAIS'),
#     (194, 201, 'U-NIVEAU_ANGLAIS'),
#     (205, 213, 'U-OTHER_LANGUAGE')]}),
#  ('Mm Competences    ortice BUREAUTIQUE  a]a[a-]eeles ve fe    S41  "4S ANGLAIS',
#   {'entities': []}),
#  ('Competences', {'entities': []}),
#  ("Atouts    Qualites organisationnelles  Analytique    Competences relationnelles  Esprit d'equipe    Adaptabilite    Informatique  Pack office: Parfaite maitrise  (Fonctions avancees d'Excel et Access)    MMS HO  SAP    Langues  Arabe_ : langue maternelle  Anglais : competences professionnelles    Italien : Notions",
#   {'entities': [(130, 134, 'B-SKILLS'),
#     (135, 141, 'L-SKILLS'),
#     (182, 189, 'U-SKILLS'),
#     (193, 199, 'U-SKILLS'),
#     (204, 207, 'U-SKILLS'),
#     (208, 210, 'U-SKILLS'),
#     (212, 215, 'U-SKILLS'),
#     (228, 234, 'U-OTHER_LANGUAGE'),
#     (256, 263, 'U-ANGLAIS'),
#     (266, 277, 'B-NIVEAU_ANGLAIS'),
#     (278, 294, 'L-NIVEAU_ANGLAIS'),
#     (298, 305, 'U-OTHER_LANGUAGE')]}),
#  ('are yale)  Maitrise de Word, Excel et PowerPoint',
#   {'entities': [(23, 27, 'U-SKILLS'),
#     (29, 34, 'U-SKILLS'),
#     (38, 48, 'U-SKILLS')]}),
#  ('LANGUES    Anglais - Bilingue [TOEIC 960/990)    Espagnol - Intermediaire',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 29, 'U-NIVEAU_ANGLAIS'),
#     (49, 57, 'U-OTHER_LANGUAGE')]}),
#  ('COMPETENCES CLEFS    e Manager,    SI ANArcINAcio1    PMapsrol Alc l kom o1 MNO (ol Siol 6    << Organiser,    << Negocier,    - Batir des relations interpersonnelles solides,  << Motiver mes collaborateurs    << Developper un reseau de partenaires,    << Gerer simultanement des projets complexes',
#   {'entities': []}),
#  ('LANGUES    Anglais: niveau B1  Espagnol : niveau A2    INFORMATIQUE    Pack office',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (20, 26, 'B-NIVEAU_ANGLAIS'),
#     (27, 29, 'L-NIVEAU_ANGLAIS'),
#     (31, 39, 'U-OTHER_LANGUAGE'),
#     (71, 75, 'B-SKILLS'),
#     (76, 82, 'L-SKILLS')]}),
#  ('LANGUES    Anglais : Operationnel  Espagnol : Scolaire  Tamoul : Langue maternelle',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 33, 'U-NIVEAU_ANGLAIS'),
#     (35, 43, 'U-OTHER_LANGUAGE')]}),
#  ("COMPETENCES    e __ Analyse des regles fiscales applicables    o Etude de marche (quantitative/qualitative)    e Maitrise de l'ensemble des techniques  bancaires    deg Elaboration strategie marketing (produit  bancaire)    e Analyse du comportement des clients (via :  compte bancaire, releves de comptes etc.)    e Calcul des couts du credit mobilier et  immobilier    e Creation base de donnees pour un  portefeuille clientele    deg Travail en equipe mais aussi en autonomie    e Organiser son travail    INFORMATIQUE : Pack Office, Outlook, IBM,  RMPM, Kosmos, Lotus, BOM, VISA Online,  PRIVALIA, ACS, IHR, FATCA, GED, Contact, Gmail,  lIOS, Photoshop, SESAM, Web To Host, PRIZE,  ACINT, Facturia, SPART, Applifax, Dexter, Ceryx,  aKa galoss",
#   {'entities': [(524, 528, 'B-SKILLS'),
#     (529, 535, 'L-SKILLS'),
#     (537, 544, 'U-SKILLS'),
#     (546, 549, 'U-SKILLS'),
#     (552, 556, 'U-SKILLS'),
#     (558, 564, 'U-SKILLS'),
#     (566, 571, 'U-SKILLS'),
#     (573, 576, 'U-SKILLS'),
#     (578, 582, 'B-SKILLS'),
#     (583, 589, 'L-SKILLS'),
#     (592, 600, 'U-SKILLS'),
#     (602, 605, 'U-SKILLS'),
#     (607, 610, 'U-SKILLS'),
#     (612, 617, 'U-SKILLS'),
#     (619, 622, 'U-SKILLS'),
#     (624, 631, 'U-SKILLS'),
#     (633, 638, 'U-SKILLS'),
#     (641, 645, 'U-SKILLS'),
#     (647, 656, 'U-SKILLS'),
#     (658, 663, 'U-SKILLS'),
#     (665, 668, 'U-SKILLS'),
#     (678, 683, 'U-SKILLS'),
#     (686, 691, 'U-SKILLS'),
#     (693, 701, 'U-SKILLS'),
#     (703, 708, 'U-SKILLS'),
#     (710, 718, 'U-SKILLS'),
#     (720, 726, 'U-SKILLS'),
#     (728, 733, 'U-SKILLS')]}),
#  ("COMPETENCES EN  INFORMATIQUE    e Systemes d'informations : ERP ODOO  Sy NEE (r)  e Progiciel logistique : WMS TMS  C/ Pack office, EXCEL : TCD, Recherche  ae  COMPETENCES ET    SAVOIR FAIRE    e Traitements et analyse de donnees  e Construction de gamme    e Analyse des besoins clients    Retail, PAP , mobilier",
#   {'entities': [(60, 63, 'U-SKILLS'),
#     (107, 110, 'U-SKILLS'),
#     (111, 114, 'U-SKILLS'),
#     (84, 93, 'B-SKILLS'),
#     (94, 104, 'L-SKILLS'),
#     (119, 123, 'B-SKILLS'),
#     (124, 130, 'L-SKILLS'),
#     (132, 137, 'U-SKILLS')]}),
#  ('Informatique  LOGICIELS    e Pack Office : WORD, EXCEL, POWERPOINT, ACCESS, OUTLOOK    e CRM : Microsoft dynamics 365, Trailhead by Salesforce certifications Resultat  obtenu(Badges +6)    e Cloud working : Kalilab    eAutres logiciels : Visio, Adobe Acrobate, GanttProject, Reseaux sociaux, Zoom',
#   {'entities': [(29, 33, 'B-SKILLS'),
#     (34, 40, 'L-SKILLS'),
#     (43, 47, 'U-SKILLS'),
#     (49, 54, 'U-SKILLS'),
#     (56, 66, 'U-SKILLS'),
#     (68, 74, 'U-SKILLS'),
#     (76, 83, 'U-SKILLS'),
#     (89, 92, 'U-SKILLS'),
#     (95, 104, 'U-SKILLS'),
#     (132, 142, 'U-SKILLS'),
#     (245, 250, 'B-SKILLS'),
#     (251, 259, 'L-SKILLS'),
#     (261, 273, 'U-SKILLS'),
#     (275, 282, 'B-SKILLS'),
#     (283, 290, 'L-SKILLS'),
#     (292, 296, 'U-SKILLS')]}),
#  ('eye Naya Pee Lalor] oe OP  Lingala C2', {'entities': []}),
#  ('Langues: Tiere 10  Frangais Langue maternelle    Anglais Intermediaire  TOIEC en cours',
#   {'entities': [(49, 56, 'U-ANGLAIS'), (57, 70, 'U-NIVEAU_ANGLAIS')]}),
#  ('Maitrise de la suite office :    Microsoft  Word    Excel  Power Point    Maitrise des progiciels de  gestion :    SAP    Bl    EBP    Ciel Compta Evolution  Ciel Paye Evolution  OFeF-1    Bloomberg software  (notion)',
#   {'entities': [(33, 42, 'U-SKILLS'),
#     (44, 48, 'U-SKILLS'),
#     (52, 57, 'U-SKILLS'),
#     (59, 64, 'B-SKILLS'),
#     (65, 70, 'L-SKILLS'),
#     (115, 118, 'U-SKILLS'),
#     (122, 124, 'U-SKILLS'),
#     (128, 131, 'U-SKILLS'),
#     (135, 139, 'U-SKILLS'),
#     (189, 198, 'U-SKILLS')]}),
#  ("Competences         e Leadership : gott des responsabilites,  coordination d'une equipe, esprit de cohesion    C/ Relationnel : diplomatie, sens de l'initiative,  discretion, adaptation    C/ Analyse : capacite de raisonnement, esprit de  synthese, prise de decision    e Langue : bilingue anglais, fortes capacites    redactionnelles, pack office",
#   {'entities': [(290, 297, 'U-ANGLAIS'),
#     (281, 289, 'L-NIVEAU_ANGLAIS'),
#     (336, 340, 'B-SKILLS'),
#     (341, 347, 'L-SKILLS')]}),
#  ("Aptitudes    e Microsoft Office, Opera Software, Salesforce,  Nova software, Prezi, Stata    e Project Management    C/ Budgetisation et analyse des coats    e Presentation de KPI's    C/ Formation d'equipe de commerciaux",
#   {'entities': [(15, 24, 'B-SKILLS'),
#     (25, 31, 'L-SKILLS'),
#     (33, 38, 'U-SKILLS'),
#     (39, 47, 'U-SKILLS'),
#     (49, 59, 'U-SKILLS'),
#     (62, 66, 'U-SKILLS'),
#     (77, 82, 'U-SKILLS'),
#     (84, 89, 'U-SKILLS')]}),
#  ('Langues    a sd1 TL at-bat aya Ue) ame tok T    e Intermediaire: Espagnol, Italien',
#   {'entities': [(65, 73, 'U-OTHER_LANGUAGE'), (75, 82, 'U-OTHER_LANGUAGE')]}),
#  ('VNU  ATOUTS - Rigueur >> Autonomie    * Organisation * Polyvalence  - Dyunamisme = Sens des priorites',
#   {'entities': []}),
#  ("COMPETENCES    Connaissances  Informatiques :  Maitrise du Pack Office et du  CRM.    Langues etrangeres :  Arabe : bilingue  Anglais : scolaire    Management d'equipe :  Formation effectuee au sein de  l'organisme NOVAREPE    (http://www.novarepe.fr/)",
#   {'entities': [(59, 63, 'B-SKILLS'),
#     (64, 70, 'L-SKILLS'),
#     (78, 81, 'U-SKILLS'),
#     (108, 113, 'U-OTHER_LANGUAGE'),
#     (126, 133, 'U-ANGLAIS'),
#     (136, 144, 'U-NIVEAU_ANGLAIS')]}),
#  ('Langues    Anglais : Courant, professionnel et  commercial    Espagnol : courant    Informatique    Word, Excel, PwPoint, SIRH',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 28, 'U-NIVEAU_ANGLAIS'),
#     (62, 70, 'U-OTHER_LANGUAGE'),
#     (100, 104, 'U-SKILLS'),
#     (106, 111, 'U-SKILLS'),
#     (113, 120, 'U-SKILLS'),
#     (122, 126, 'U-SKILLS')]}),
#  ('COMPETENCES BUREAUTIQUES:  EXCEL, POWERPOINT, WORD, Oracle, Orchestra, TRETRAWIN, TOTALIMMO',
#   {'entities': [(27, 32, 'U-SKILLS'),
#     (34, 44, 'U-SKILLS'),
#     (46, 50, 'U-SKILLS'),
#     (52, 58, 'U-SKILLS'),
#     (60, 69, 'U-SKILLS'),
#     (71, 80, 'U-SKILLS'),
#     (82, 91, 'U-SKILLS')]}),
#  ('COMPETENCES    Langues  Anglais  Frangais  Allemand    STeyaayie las)    G-Suite (Google  MS Office Apps    Reseaux sociaux  Outlook Agenda  Ste :<    Adobe InDesign    Langue maternelle  Jaxeycerrsteyevetel  Limited    AGT TL  AGT TL  AGT TL  ATT TL  (c)0000  @@@00',
#   {'entities': [(24, 31, 'U-ANGLAIS'),
#     (73, 80, 'U-SKILLS'),
#     (108, 115, 'B-SKILLS'),
#     (116, 123, 'L-SKILLS'),
#     (125, 132, 'U-SKILLS'),
#     (133, 139, 'U-SKILLS'),
#     (151, 156, 'U-SKILLS'),
#     (157, 165, 'U-SKILLS')]}),
#  ('CONNAISSANCE INFORMATIQUE    Pack office, Teams, office 365, Outlook,  Lotus 6.5., Egencia, Progiciels 4D, Teapot  (Gestion des dossiers accidents du travail  et maladies  professionnelles), PR2I,  Assoconnect, Ecotiz',
#   {'entities': [(29, 33, 'B-SKILLS'),
#     (34, 40, 'L-SKILLS'),
#     (42, 47, 'U-SKILLS'),
#     (49, 55, 'B-SKILLS'),
#     (56, 59, 'L-SKILLS'),
#     (61, 68, 'U-SKILLS'),
#     (71, 76, 'U-SKILLS'),
#     (83, 90, 'U-SKILLS'),
#     (92, 102, 'U-SKILLS'),
#     (107, 113, 'U-SKILLS'),
#     (191, 195, 'U-SKILLS'),
#     (198, 209, 'U-SKILLS'),
#     (211, 217, 'U-SKILLS')]}),
#  ('COMPETENCES    Gestion de portefeuille, et reclamations  aT    Traitement administratif de dossiers  Saisie et mise en forme des documents  Ama Memeo lates ig    Gestion des stocks et etablissement des  commandes    Connaissance terminologie juridique et  medicale    Respect des delais    Accueil physique et telephonique  Organisation des deplacements    Tri, distribution, enregistrement du  courrier et gestion des messages  electroniques',
#   {'entities': []}),
#  ('OO    LANGUES  Anglais : Debutant    COMPETENCES    Outils bureautiques : Pack  Office, Sage',
#   {'entities': [(15, 22, 'U-ANGLAIS'),
#     (25, 33, 'U-NIVEAU_ANGLAIS'),
#     (74, 78, 'B-SKILLS'),
#     (80, 86, 'L-SKILLS'),
#     (88, 92, 'U-SKILLS')]}),
#  ('COMPETENCE                  x  ot    []] Office  N ax SO m2    if  x  (r)',
#   {'entities': [(41, 47, 'U-SKILLS')]}),
#  ('COMPETENCES         Maitrise des techniques de vente  Bon niveau Pack Office  Connaissance des produits et du magasin    Contact facile avec la clientele    Adaptabilite    Capacite de persuasion',
#   {'entities': [(65, 69, 'B-SKILLS'), (70, 76, 'L-SKILLS')]}),
#  ('2D Langues    Portugais C2 >    Espagnol B1 2  Anglais A2 --',
#   {'entities': [(14, 23, 'U-OTHER_LANGUAGE'),
#     (32, 40, 'U-OTHER_LANGUAGE'),
#     (47, 54, 'U-ANGLAIS'),
#     (55, 57, 'U-NIVEAU_ANGLAIS')]}),
#  ('INFORMATIQUE  fede laa    SAP', {'entities': [(26, 29, 'U-SKILLS')]}),
#  ('LANGUES  Espagnol    Anglais    Arabe',
#   {'entities': [(9, 17, 'U-OTHER_LANGUAGE'),
#     (21, 28, 'U-OTHER_LANGUAGE'),
#     (32, 37, 'U-OTHER_LANGUAGE')]}),
#  ('-- LOGICIELS --    Word, Excel, Powerpoint  Adobe    -- LANGUES ----  Anglais: Bilingue  Espagnol: Courant  Hindi: Langue  paternelle  Creole: Langue    maternelle',
#   {'entities': [(19, 23, 'U-SKILLS'),
#     (25, 30, 'U-SKILLS'),
#     (32, 42, 'U-SKILLS'),
#     (44, 49, 'U-SKILLS'),
#     (70, 77, 'U-ANGLAIS'),
#     (79, 87, 'U-NIVEAU_ANGLAIS'),
#     (89, 97, 'U-OTHER_LANGUAGE'),
#     (108, 113, 'U-OTHER_LANGUAGE'),
#     (135, 141, 'U-OTHER_LANGUAGE')]}),
#  ("COMPETENCES & LOGICIELS    COMPETENCES :  Sens de l'organisation et des responsabilites des consignes, ponctuelle  Faire preuve de diplomatie et de reactivite  Travail en equipe  Souriante et aisance relationnelle    LOGICIELS et PROGICIELS:  INFOR M3 (progiciel de gestion clients / facturation)  IGLOO SOFTWARE (progiciel de gestion clients)  AMEX (logiciel d'organisation de deplacement professionnel)  PACK OFFICE : Word, Excel, Access, PowerPoint, Outlook",
#   {'entities': [(230, 240, 'U-SKILLS'),
#     (298, 303, 'U-SKILLS'),
#     (345, 349, 'U-SKILLS'),
#     (406, 410, 'B-SKILLS'),
#     (411, 417, 'L-SKILLS'),
#     (420, 424, 'U-SKILLS'),
#     (426, 431, 'U-SKILLS'),
#     (433, 439, 'U-SKILLS'),
#     (441, 451, 'U-SKILLS'),
#     (453, 460, 'U-SKILLS')]}),
#  ("| CENTRES D'INTERET / LANGUES |    e Langues : Anglais & Espagnol niveau conversationnel  e Loisirs : voyage (Guadeloupe, Espagne, Dubai, Grece, Angleterre), musique, lecture et sortie",
#   {'entities': [(47, 54, 'U-ANGLAIS'),
#     (57, 65, 'U-OTHER_LANGUAGE'),
#     (66, 72, 'B-NIVEAU_ANGLAIS'),
#     (73, 88, 'L-NIVEAU_ANGLAIS')]}),
#  ('SOFTSKILLS    PE  Motivee  Fiable  Determinee  Polyvalente  Empathique  Passionnee',
#   {'entities': []}),
#  ('LANGUES    CC  Anglais: B1    Espagnol: A2',
#   {'entities': [(15, 22, 'U-ANGLAIS'),
#     (24, 26, 'U-NIVEAU_ANGLAIS'),
#     (30, 38, 'U-OTHER_LANGUAGE')]}),
#  ('OUTILS NUMERIQUES    Pack Office / Excel, Word bon niveau',
#   {'entities': [(21, 25, 'B-SKILLS'),
#     (26, 32, 'L-SKILLS'),
#     (35, 40, 'U-SKILLS'),
#     (42, 46, 'U-SKILLS')]}),
#  ('INFORMATIQUE    Maitrise du pack office : Word, Excel  Logiciel : Amadeus, Ciel gestion commerciale',
#   {'entities': [(28, 32, 'B-SKILLS'),
#     (33, 39, 'L-SKILLS'),
#     (42, 46, 'U-SKILLS'),
#     (48, 53, 'U-SKILLS'),
#     (66, 73, 'U-SKILLS'),
#     (75, 79, 'U-SKILLS')]}),
#  ('LANGUES    PUA AC Seem INAtc Om SP  Espagnol : niveau B2',
#   {'entities': [(36, 44, 'U-OTHER_LANGUAGE')]}),
#  ("LANGUES  FRANGAIS  ANGLAIS    BUREAUTIQUE    DACTYLOGRAPHIE  PACK OFFICE    Langue maternelle, maitrise de l'orthographe, grammaire et conjugaison.    Bonne maitrise a I'ecrit et oral.    Vitesse de 80 WPM (keyhero.com, typing-speed-test.aoeu.eu).    Maitrise de Word, Excel et PowerPoint.",
#   {'entities': [(19, 26, 'U-ANGLAIS'),
#     (61, 65, 'B-SKILLS'),
#     (66, 72, 'L-SKILLS'),
#     (263, 267, 'U-SKILLS'),
#     (269, 274, 'U-SKILLS'),
#     (278, 288, 'U-SKILLS')]}),
#  ("INFORMATIQUE    Pack Office : Word, Excel, Powerpoint,  Outlook    Logiciels : SAP, Lotus Notes, Locarchives,  AEB Badges    LANGUE    Anglais: professionnel/courant, tres bonne  maitrise a l'ecrit et parfaite comprehension a  la lecture, je suis capable d'echanger par    raeeeee",
#   {'entities': [(16, 20, 'B-SKILLS'),
#     (21, 27, 'L-SKILLS'),
#     (30, 34, 'U-SKILLS'),
#     (36, 41, 'U-SKILLS'),
#     (43, 53, 'U-SKILLS'),
#     (56, 63, 'U-SKILLS'),
#     (79, 82, 'U-SKILLS'),
#     (84, 89, 'U-SKILLS'),
#     (90, 95, 'U-SKILLS'),
#     (97, 108, 'U-SKILLS'),
#     (111, 114, 'B-SKILLS'),
#     (115, 121, 'L-SKILLS'),
#     (135, 142, 'U-ANGLAIS'),
#     (144, 157, 'U-NIVEAU_ANGLAIS')]}),
#  ("Management    Gestion de projet  Developpement RH  Animation de formation    Organisation d'evenements",
#   {'entities': []}),
#  ('Hebreu         Espagnol    Anglais    Arabe',
#   {'entities': [(0, 6, 'U-OTHER_LANGUAGE'),
#     (15, 23, 'U-OTHER_LANGUAGE'),
#     (27, 34, 'U-ANGLAIS'),
#     (38, 43, 'U-OTHER_LANGUAGE')]}),
#  ('Anglais : Fonctionnel et professionnel (1 an a Londres)  Informatique: Pack office, Pack google, CRM, SAP, File Maker',
#   {'entities': [(0, 7, 'U-ANGLAIS'),
#     (10, 21, 'B-NIVEAU_ANGLAIS'),
#     (22, 24, 'I-NIVEAU_ANGLAIS'),
#     (25, 38, 'L-NIVEAU_ANGLAIS'),
#     (71, 75, 'B-SKILLS'),
#     (76, 82, 'L-SKILLS'),
#     (84, 88, 'B-SKILLS'),
#     (89, 95, 'L-SKILLS'),
#     (97, 100, 'U-SKILLS'),
#     (102, 105, 'U-SKILLS'),
#     (107, 111, 'B-SKILLS'),
#     (112, 117, 'L-SKILLS')]}),
#  ('COMPETENCES  *ACHATS  Negociation, Gestion de projets, Analyse et expression fonctionnelle du besoin, Sourcing, Politique Strategie et processus Achats    *PRODUIT  Construction plan de collection, Sensibilite produit, Marketing, Merchandising, Aisance avec les chiffres et capacite analytique    *LANGUES  Anglais: Niveau Avance (Professionnel)  Espagnol: Niveau Debutant (Scolaire)    *INFORMATIQUE    * Pack Microsoft Office (Word, Excel, Powerpoint, Access, Publisher)  C/ EBP, MS PROJECT    C/ SAGE COMPTA (Notions scolaires)    C/ SAP (Notions)    C/ Ulysse, ISIS, AS400',
#   {'entities': [(307, 314, 'U-ANGLAIS'),
#     (316, 322, 'B-NIVEAU_ANGLAIS'),
#     (323, 329, 'L-NIVEAU_ANGLAIS'),
#     (347, 355, 'U-OTHER_LANGUAGE'),
#     (406, 410, 'B-SKILLS'),
#     (411, 420, 'I-SKILLS'),
#     (421, 427, 'L-SKILLS'),
#     (429, 433, 'U-SKILLS'),
#     (435, 440, 'U-SKILLS'),
#     (442, 452, 'U-SKILLS'),
#     (454, 460, 'U-SKILLS'),
#     (462, 471, 'U-SKILLS'),
#     (477, 480, 'U-SKILLS'),
#     (482, 484, 'B-SKILLS'),
#     (485, 492, 'L-SKILLS'),
#     (496, 497, 'U-SKILLS'),
#     (499, 503, 'B-SKILLS'),
#     (504, 510, 'L-SKILLS'),
#     (537, 540, 'U-SKILLS'),
#     (557, 563, 'U-SKILLS'),
#     (565, 569, 'U-SKILLS'),
#     (571, 576, 'U-SKILLS')]}),
#  ('COMPETENCES  ed UCMa me Colittinted enti mem deeded    C/ Etablir les paies via paytit    C/ Rediger des contrats de contrat de travail, avenant    e Gerer les affiliations salariees aux organismes sociaux    e Verification et/ou saisie des elements variables,  acomptes, ATD    e Gestion des arret maladie , accident de travail    C/ Suivi des notes de frais    C/ Etablir les registres du personnel et tableau de bord',
#   {'entities': []}),
#  ('COMPETENCES INFORMATIQUES ET  LINGUISTIQUES    Pratique protessionelle de word, Excel, Powerpoint  Sage Paie    eMail    Yooz    Anglais B2 , Espagnol B2',
#   {'entities': [(74, 78, 'U-SKILLS'),
#     (80, 85, 'U-SKILLS'),
#     (87, 97, 'U-SKILLS'),
#     (99, 103, 'B-SKILLS'),
#     (104, 108, 'L-SKILLS'),
#     (112, 117, 'U-SKILLS'),
#     (121, 125, 'U-SKILLS'),
#     (129, 136, 'U-NIVEAU_ANGLAIS'),
#     (137, 139, 'U-ANGLAIS'),
#     (142, 150, 'U-OTHER_LANGUAGE')]}),
#  ('excellent sens de la  communication  Gestionnaire rigoureux  Disponible    Fin negociateur    Focus Service a la clientele  Recrutement',
#   {'entities': []}),
# ...
#     (29, 33, 'U-SKILLS'),
#     (60, 66, 'U-SKILLS'),
#     (68, 72, 'U-SKILLS'),
#     (75, 80, 'U-SKILLS'),
#     (83, 93, 'U-SKILLS')]}),
#  ('COMPETENCES  Administrative  Organisation des plannings et reunion, accueil physique et telephonique, gestion des rendez-vous  Suivi du personnel, compte rendu, tri et archivages, saisie des notes comptables, gestions des fournitures  NOURI welsKn  (Ati Ka te  Elaboration des offres commerciales, devis et pro-forma, saisie commandes,  Gestions des contrats, facturation, gestion des litiges, gestions portes feuilles clients, recouvrements,  suivi des livraisons, reglements fournisseurs.',
#   {'entities': []}),
#  ('LANGUES & INFORMATIQUE    C/ Anglais : experimente -- TOEIC niveau C1 (juin 2019 : 965 points)  deg Logiciels : Pack Office, Sales Force, Oracle Sales Cloud, Frontrage',
#   {'entities': [(29, 36, 'U-ANGLAIS'),
#     (39, 50, 'B-NIVEAU_ANGLAIS'),
#     (54, 59, 'I-NIVEAU_ANGLAIS'),
#     (60, 66, 'I-NIVEAU_ANGLAIS'),
#     (67, 69, 'L-NIVEAU_ANGLAIS'),
#     (112, 116, 'B-SKILLS'),
#     (117, 123, 'L-SKILLS'),
#     (125, 130, 'B-SKILLS'),
#     (131, 136, 'L-SKILLS'),
#     (138, 144, 'U-SKILLS')]}),
#  ('Francais  Anglais  Allemand  Espagnol',
#   {'entities': [(10, 17, 'U-ANGLAIS'),
#     (19, 27, 'U-OTHER_LANGUAGE'),
#     (29, 37, 'U-OTHER_LANGUAGE')]}),
#  ("oP    TECHNICO-COMMERCIAL    << Analyse des besoins    << Developpement du portefeuille client  << Elaboration de l'offre    e<< Phoning et mailing commercial    << Suivi des objectifs    - Detection et traitement de leads    Pamavd =) |i (omlee-ik-181(6[ 01>)    CONSEILLER COMMERCIAL    << Conception et realisation des supports    C/ Identification et comprehension de la  concurrence    << Gestion des prospects    C/ Participation aux actions de Marketing    << Participation aux salons et foires    << Suivi des partenaires    BUSINESS DEVELOPPER    << Accompagnement et suivi de la clientele  << Developpement de nouveaux marche    << Expertise dans la vente    << Generation des revenus    << Prospection de leads    << Traitement des commandes    COMMUNITY MANAGEMENT    << Animation de la communaute    << Connaissance du SMO    << Organisation et mise en place  d'evenement    << Planification et creation de contenus    << Veille concurrentielle, commerciale et  d'e-reputation    << Maitrise du graphisme et du Design",
#   {'entities': []}),
#  ("SYSTEMES & LOGICIELS    Administration Hyper V / VMware 6.5  Pratique ITIL - Windows NT d 2016  Bonne maitrise des environnements  LAN, SAN, WAN    Bonne experience dans le support  d'une large gamme de serveurs  Supervision NAGIOS    LANGUES    Anglais: intermediaire &Technique  Francais : langue Maternelle",
#   {'entities': [(77, 84, 'U-SKILLS'),
#     (131, 134, 'U-SKILLS'),
#     (136, 139, 'U-SKILLS'),
#     (141, 144, 'U-SKILLS'),
#     (225, 231, 'U-SKILLS'),
#     (246, 253, 'U-ANGLAIS'),
#     (255, 268, 'B-NIVEAU_ANGLAIS'),
#     (269, 279, 'L-NIVEAU_ANGLAIS'),
#     (49, 55, 'U-SKILLS')]}),
#  ("Competences humaines    w Gestion de conflit / resistance au stress  @ Sociabilite / Enthousiasme    w Sens des responsabilites et fiabilite    w Capacite d'organisation et d'initiative    @ Creativite et curiosite    eon) X-tev kee    CRM sur Sage eeee@e  Gercop x  Galian e@e@e0e  Locapass (a  Langues    PVCS eee0e",
#   {'entities': [(236, 239, 'U-SKILLS'),
#     (244, 248, 'U-SKILLS'),
#     (257, 263, 'U-SKILLS'),
#     (283, 291, 'U-SKILLS'),
#     (267, 273, 'U-SKILLS')]}),
#  ('LOGICIELS    Word, Excel, PowerPoint.',
#   {'entities': [(13, 17, 'U-SKILLS'),
#     (19, 24, 'U-SKILLS'),
#     (26, 36, 'U-SKILLS')]}),
#  ('LANGUES & INFORMATIQUE         e Anglais : Capacites professionnelles  completes (niveau B2)',
#   {'entities': [(33, 40, 'U-ANGLAIS'),
#     (43, 52, 'B-NIVEAU_ANGLAIS'),
#     (53, 69, 'I-NIVEAU_ANGLAIS'),
#     (71, 80, 'I-NIVEAU_ANGLAIS'),
#     (82, 88, 'I-NIVEAU_ANGLAIS'),
#     (89, 91, 'L-NIVEAU_ANGLAIS')]}),
#  ('e Bureautique : Maitrise du pack Office  e Logiciel CRM : Adonix X3, V6, SAGE  e Gestion de projet : MS Project    e Connaissance XML, HTML    e Internet - Photoshop    e Data visualisation',
#   {'entities': [(28, 32, 'B-SKILLS'),
#     (33, 39, 'L-SKILLS'),
#     (52, 55, 'U-SKILLS'),
#     (58, 64, 'U-SKILLS'),
#     (69, 71, 'U-SKILLS'),
#     (73, 77, 'U-SKILLS'),
#     (130, 133, 'U-SKILLS'),
#     (135, 139, 'U-SKILLS'),
#     (156, 165, 'U-SKILLS')]}),
#  ("petences  Technique d'accueil  physique / telephonique et de  recrutement.         Planifier : reunions, rendez-  vous, entretiens,  deplacement, dejeuner    Organiser : evenement, cocktail,  soiree equipes, AG, Comites    Recrutement : rediger des  annonces d'emploi, sourcing,  entretiens telephoniques et/ou  physiques (tests, evaluations, mise  en situation...)    Logiciel    H6etesse d'accueil standardiste    Pack office, Sage, HRA, Area peor Ta ol  Langue: Anglais BUC iC Cleo eel ey)    Comite d'entreprise << Deloitte >> -  Neuilly sur seine (92)    Obtention du B.A.F.A.    Benevole Association : Panier  solidaire de Rueil",
#   {'entities': [(416, 420, 'B-SKILLS'),
#     (421, 427, 'L-SKILLS'),
#     (429, 433, 'U-SKILLS'),
#     (435, 438, 'U-SKILLS'),
#     (440, 444, 'U-SKILLS'),
#     (465, 472, 'U-ANGLAIS')]}),
#  ('Microsoft Office, APM, Access, Oracle, Sage 100, AS 400  Anglais (scolaire), arabe (parle)  Randonnes, Cinema, Sport',
#   {'entities': [(0, 9, 'B-SKILLS'),
#     (10, 16, 'L-SKILLS'),
#     (18, 21, 'U-SKILLS'),
#     (23, 29, 'U-SKILLS'),
#     (31, 37, 'U-SKILLS'),
#     (39, 43, 'U-SKILLS'),
#     (49, 51, 'U-SKILLS'),
#     (57, 64, 'U-ANGLAIS'),
#     (66, 74, 'U-NIVEAU_ANGLAIS'),
#     (77, 82, 'U-OTHER_LANGUAGE')]}),
#  ("A 8 ee ee ee ee ee    COMPETENCES    Organisation et Gestion    a GR a MGR GEE    Tenue d'agendas, gestion de planning  Traitement et suivi de dossiers clients  Organisation de reunions, de deplacements  Redaction de contrats, Proces-verbaux,  lettres de mission, notes de service    Mise en page, synthese de documents  Gestion de formation    Gestion de cotisations, ordres de missions,  tickets resto    Accueil des nouveaux entrants    Juridique exceptionnel, formalites aupres du  Greffe    ala al oe al aE    Coordination et Suivi    Traitement du courrier    Accueil physique et telephonique    Interface partenaires internes /externes  Visite medicale, habilitations    Integration des elements variables de Paie  Suivi comptabilite clients et fournisseurs  Paiement fournisseurs    Bureautigue et Langues    Word, Excel, PowerPoint, Outlook  Anglais (intermediaire), Malgache courant",
#   {'entities': [(817, 821, 'U-SKILLS'),
#     (823, 828, 'U-SKILLS'),
#     (830, 840, 'U-SKILLS'),
#     (842, 849, 'U-SKILLS'),
#     (851, 858, 'U-ANGLAIS'),
#     (860, 873, 'U-NIVEAU_ANGLAIS'),
#     (876, 884, 'U-OTHER_LANGUAGE')]}),
#  ("Compeetences    C/ Management d'equipe.  C/ Elaboration, gestion et optimisation de Budget.    * Gestion des locaux: pilotage des prestataires et suivi  des differentes interventions.    * Gestion de projet: pilotage des travaux et  elena erxaeno NLS    C/ Recherche de prestataires et mise en place d'appels  d'offres et/ou partenariats commerciaux.    * Gestion de badges, flotte automobile, flotte mobile,  imprimerie et assurance.    C/ Conception et suivi de tableaux de bord.",
#   {'entities': []}),
#  ('Langues    Anglais : courant.  Espagnol : bilingue    MK Mea Lis    Pack Office  NyAN a',
#   {'entities': [(11, 18, 'U-ANGLAIS'),
#     (21, 28, 'U-NIVEAU_ANGLAIS'),
#     (31, 39, 'U-OTHER_LANGUAGE'),
#     (68, 72, 'B-SKILLS'),
#     (73, 79, 'L-SKILLS')]}),
#  ('Langues    Francais, anglais, arabe, allemand  Qualites professionnelles  Meethodique, autonome,    Curieux.',
#   {'entities': [(21, 28, 'U-ANGLAIS'),
#     (30, 35, 'U-OTHER_LANGUAGE'),
#     (37, 45, 'U-OTHER_LANGUAGE')]}),
#  ('LOGICIELS LANGUES    Word > Anglais :  Excel Intermediaire  PowerPoint > Espagnol :    Intermediaire',
#   {'entities': [(21, 25, 'U-SKILLS'),
#     (28, 35, 'U-ANGLAIS'),
#     (39, 44, 'U-SKILLS'),
#     (60, 70, 'U-SKILLS'),
#     (73, 81, 'U-OTHER_LANGUAGE')]}),
#  ("COMPETENCES PROFESSIONNELLES  LINGUISTIQUES    Anglais : Avance (TOEIC : 970) - Allemand : Niveau intermediaire  Italien : Notions    INFORMATIQUE    Pack Office - Google AdWords - Per Angusta - Salestorces    ACHATS    Veille concurrentielle et marche afin de trouver de nouveaux  fournisseurs    Anticiper les evolutions, les risques et opportunites, capter les  innovations    Aider a la mise en ceuvre d'outils et process permettant  l'amelioration continue de la performance du Service Achats  Identitier les gisements d'economies et les leviers    d'optimisation des achats ;    Lancement RFO RFI    Etude Make or Buy pour un fabricant de cosmetique : un  fabricant cosmetique nous a sollicite afin de lui fournir une etude  sur la meilleure strategie 4 adopter pour repondre a l'augmentati  de la demande. Une analyse des fournisseurs, des cotits de  fabrication et une solution Make and Buy a ete rendue au    fabricant. (Projet academico-professionnel)    COMMERCIAL  e Gestion de portefeuille    e Realisation de propositions commerciales et devis",
#   {'entities': [(47, 54, 'U-ANGLAIS'),
#     (57, 63, 'B-NIVEAU_ANGLAIS'),
#     (65, 70, 'I-NIVEAU_ANGLAIS'),
#     (73, 76, 'L-NIVEAU_ANGLAIS'),
#     (80, 88, 'U-OTHER_LANGUAGE'),
#     (113, 120, 'U-OTHER_LANGUAGE'),
#     (150, 154, 'B-SKILLS'),
#     (155, 161, 'L-SKILLS'),
#     (164, 170, 'B-SKILLS'),
#     (171, 178, 'L-SKILLS'),
#     (195, 206, 'U-SKILLS')]}),
#  ("mm Rea er    - Accueil telephonique  - Envoi de mail    - Relation client    - Archivage    - Prise de rendez-vous  - Ecoute    - Procedures civiles    - Procedures administratives  - RPVA - ICARPA    - Redaction d'actes    - Facturation    - Gestion agenda    - Calendrier d'audience  - Convocation AGO/AGE",
#   {'entities': []}),
#  ('C0) =a =O ate a    Excel : Avance Espagnol : Langue maternelle    Microsoft Dynamics : Avance Catalan : Langue maternelle    SAP : Moyen Francais : Avance    RaVMAN TSU BaUO 18 Anglais ; Avance',
#   {'entities': [(19, 24, 'U-SKILLS'),
#     (34, 42, 'U-OTHER_LANGUAGE'),
#     (66, 75, 'B-SKILLS'),
#     (76, 84, 'L-SKILLS'),
#     (94, 101, 'U-OTHER_LANGUAGE'),
#     (125, 128, 'U-SKILLS'),
#     (177, 184, 'U-ANGLAIS'),
#     (187, 193, 'U-NIVEAU_ANGLAIS')]}),
#  ('Langues    Kabyle : langue maternelle  Anglais : courant    Arabe : courant  Allemand : notion',
#   {'entities': [(11, 17, 'U-OTHER_LANGUAGE'),
#     (39, 46, 'U-ANGLAIS'),
#     (49, 56, 'U-NIVEAU_ANGLAIS'),
#     (60, 65, 'U-OTHER_LANGUAGE'),
#     (77, 85, 'U-OTHER_LANGUAGE')]}),
#  ('Competences    Word, Excel, PowerPoint, Gantt Project, TeamViewer, Outlook, Gmail, Visual, internet et reseaux sociaux',
#   {'entities': [(15, 19, 'U-SKILLS'),
#     (21, 26, 'U-SKILLS'),
#     (28, 38, 'U-SKILLS'),
#     (40, 45, 'U-SKILLS'),
#     (55, 65, 'U-SKILLS'),
#     (67, 74, 'U-SKILLS'),
#     (76, 81, 'U-SKILLS'),
#     (83, 89, 'U-SKILLS'),
#     (103, 110, 'B-SKILLS'),
#     (111, 118, 'L-SKILLS')]}),
#  ('COMPTENCES PROFESSONNELLES    Logiciel Comptable  Analyse financiere  Comptabilite Generale  Gestion de tresorerie  Contrele de Gestion  Fiscalite    Anglais',
#   {'entities': [(150, 157, 'U-ANGLAIS')]}),
#  ('COMPETENCES    Administratives :         - PACK OFFICE    - Assurer un accueil physique  et telephonique    - Planifier les salles de reunion    Commerciales:    - Saisie des bons de commande  oan esc4i1 een ele  commandes sur Excel    oma keycd elon lent] Mea ely ane] 6s  - Archiver / classer les dossiers  - Gestion du courrier    - Gestion de la reprographie    - Rapprochement bon de  commande -- bon de livraison',
#   {'entities': [(43, 47, 'B-SKILLS'), (48, 54, 'L-SKILLS')]}),
#  ("Management    Gestion de projet  Developpement RH  Animation de formation    Organisation d'evenements",
#   {'entities': []}),
#  ('Hebreu         Espagnol    Anglais    Arabe',
#   {'entities': [(0, 6, 'U-OTHER_LANGUAGE'),
#     (15, 23, 'U-OTHER_LANGUAGE'),
#     (27, 34, 'U-ANGLAIS'),
#     (38, 43, 'U-OTHER_LANGUAGE')]}),
#  ("LANGUES ET CENTRES D'INTERETS    Langues : Anglais et Espagnol : Niveau intermediaire, Arabe : Bilingue  Logiciels maitrises : Pack office : Word, Excel, PowerPoint    Sports : Football (7 ans), Entraineur et arbitre des equipes de 11 ans  Voyages : Espagne, Pays-Bas, Maroc",
#   {'entities': [(43, 50, 'U-ANGLAIS'),
#     (54, 62, 'U-OTHER_LANGUAGE'),
#     (65, 71, 'B-NIVEAU_ANGLAIS'),
#     (72, 85, 'L-NIVEAU_ANGLAIS'),
#     (87, 92, 'U-OTHER_LANGUAGE'),
#     (127, 131, 'B-SKILLS'),
#     (132, 138, 'L-SKILLS'),
#     (141, 145, 'U-SKILLS'),
#     (147, 152, 'U-SKILLS'),
#     (154, 164, 'U-SKILLS')]}),
#  ('huuund    Niveau tres bon    2003 : BULATS (Intermediate) - UNIVERSITY OF CAMBRIDGE  1995 : KET (Elementary) - UNIVERSITY OF CAMBRIDGE',
#   {'entities': []}),
#  ('|    Pack Office : bonne utilisation    Loisirs : Musicien depuis 1994 (guitare, basse...)  Sport : Pilates',
#   {'entities': [(5, 9, 'B-SKILLS'), (10, 16, 'L-SKILLS')]}),
#  ('INFORMATIQUE    Excel (formation TOSA)  ERP    Word    Power Point    Mi Zel uel aetss    ATiTebs<    GanttProject    Trello    COMPETENCES  PROFESSIONNELLES    FINANCIERES    Elaboration de budget  Analyse financiere    Gestion de la tresorerie  Evaluation des entreprises  Methodes de consolidations,  normes IRFS    Gestion des risques  financiers    Gestion du financement des  equipements    COMMUNICATION    Reporting    Veille financiere  Redaction synthetique  Force de proposition  Paertesreccveatayl    Gestion de projet    Business plan    Infographie    Elaboration de tableaux de  bord',
#   {'entities': [(16, 21, 'U-SKILLS'),
#     (40, 43, 'U-SKILLS'),
#     (47, 51, 'U-SKILLS'),
#     (55, 60, 'B-SKILLS'),
#     (61, 66, 'L-SKILLS')]}),
#  ("COMPETENCES  PERSONNELLES    7 Rigoureuse  =  Capacite d'analyse  =>> Organisation    COMPETENCES  LINGUISTIQUES    pie ENGLISH Professionnal  = ESPANOL Intermedio",
#   {'entities': [(120, 127, 'U-ANGLAIS'),
#     (128, 141, 'U-NIVEAU_ANGLAIS'),
#     (145, 152, 'U-OTHER_LANGUAGE')]}),
#  ('INFORMATIQUE  Excel et Word    Internet    Outlook    BUREAUTIQUE    Prise de notes    Classement des dossiers et  archivage    Tableaux de suivi (Excel)  Gestion des mails    et redaction du courrier    Langues         Anglais intermediaire    Bon relationnel',
#   {'entities': [(14, 19, 'U-SKILLS'),
#     (23, 27, 'U-SKILLS'),
#     (43, 50, 'U-SKILLS'),
#     (220, 227, 'U-ANGLAIS'),
#     (228, 241, 'U-NIVEAU_ANGLAIS')]}),
#  ('COMPETENCES if    Active Directory, Shell, Powershell, VMWare, Passerelle l  Edge, FTP, SCP, Samba, Apache, Squid, IPTables, GLP], _E  Snow, Remedy, VLAN, DHCP, Centreon, WDS, PXE,    Fillezilla, CloneZilla, FortiClient, Masterisation, Citrix Studio,  RDP, SCCM, TeamViewer, Anydesk, VNC, TSE, SSH,    Office 365, Exchange, Symantec EndPoint, Eset NOD32,  HTML, CSS, PHP, SQL, Drupal, Bootstrap, PhoMyAdmin.',
#   {'entities': [(18, 24, 'B-SKILLS'),
#     (25, 34, 'L-SKILLS'),
#     (36, 41, 'U-SKILLS'),
#     (43, 53, 'U-SKILLS'),
#     (55, 61, 'U-SKILLS'),
#     (63, 73, 'U-SKILLS'),
#     (77, 81, 'U-SKILLS'),
#     (83, 86, 'U-SKILLS'),
#     (88, 91, 'U-SKILLS'),
#     (93, 98, 'U-SKILLS'),
#     (100, 106, 'U-SKILLS'),
#     (108, 113, 'U-SKILLS'),
#     (115, 123, 'U-SKILLS'),
#     (125, 128, 'U-SKILLS'),
#     (135, 139, 'U-SKILLS'),
#     (141, 147, 'U-SKILLS'),
#     (149, 153, 'U-SKILLS'),
#     (155, 159, 'U-SKILLS'),
#     (161, 169, 'U-SKILLS'),
#     (171, 174, 'U-SKILLS'),
#     (176, 179, 'U-SKILLS'),
#     (184, 194, 'U-SKILLS'),
#     (196, 206, 'U-SKILLS'),
#     (208, 219, 'U-SKILLS'),
#     (221, 234, 'U-SKILLS'),
#     (236, 242, 'B-SKILLS'),
#     (243, 249, 'L-SKILLS'),
#     (252, 255, 'U-SKILLS'),
#     (257, 261, 'B-SKILLS'),
#     (263, 273, 'U-SKILLS'),
#     (275, 282, 'U-SKILLS'),
#     (284, 287, 'U-SKILLS'),
#     (289, 292, 'U-SKILLS'),
#     (294, 297, 'U-SKILLS'),
#     (309, 312, 'L-SKILLS'),
#     (314, 322, 'U-SKILLS'),
#     (324, 332, 'B-SKILLS'),
#     (333, 341, 'L-SKILLS'),
#     (343, 347, 'U-SKILLS'),
#     (348, 353, 'U-SKILLS'),
#     (356, 360, 'U-SKILLS'),
#     (302, 308, 'B-SKILLS'),
#     (362, 365, 'U-SKILLS'),
#     (367, 370, 'U-SKILLS'),
#     (372, 375, 'U-SKILLS'),
#     (377, 383, 'U-SKILLS'),
#     (385, 394, 'U-SKILLS'),
#     (396, 406, 'U-SKILLS')]})]

# %% [markdown]
# ### Format Datas apres transformation --> (texte, listes de tuples)

# %%
list(set([tuple_[2] for tuple_ in DATA[0][1]['entities']]))
# Out:
# ['U-SKILLS']

# %% [markdown]
# ### Modeling -- Ci dessous 2 differents NER

# %%
def train_model_2(LABEL, TRAIN):
    # Setting up the pipeline and entity recognizer.
    nlp = spacy.blank('fr')  # create blank Language class
    print("Created blank 'fr' model")
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe('ner')
    else:
        ner = nlp.get_pipe('ner')
    # Add new entity labels to entity recognizer
    for i in LABEL:
        ner.add_label(i)
    # Inititalizing optimizer
    optimizer = nlp.begin_training()
    # Get names of other pipes to disable them during training to train # only NER and update the weights
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        for itn in range(40):
            random.shuffle(TRAIN)
            losses = {}
            batches = minibatch(TRAIN, 
                                size=compounding(4., 32., 1.001))
            for batch in batches:
                for text, annotations in batch:
                    # create Example
                    doc = nlp.make_doc(text)
                    example = Example.from_dict(doc, annotations)
                    # Update the model
                    nlp.update([example], losses=losses, drop=0.3)
    return nlp

# %%
LABEL_skills = ["U-SKILLS", "B-SKILLS", "I-SKILLS", "L-SKILLS", "U-ANGLAIS", "U-NIVEAU_ANGLAIS",
    "B-NIVEAU_ANGLAIS", "I-NIVEAU_ANGLAIS", "L-NIVEAU_ANGLAIS", "U-OTHER_LANGUAGE"]
LABEL_exp_pro = ['B-JobTitle','B-DateExp','I-DateExp','L-JobTitle','L-DateExp','I-JobTitle',
 'U-Company','L-Company','B-Company']

nlp = train_model_2(LABEL_skills, TRAIN)
# Out:
# Created blank 'fr' model
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(54, 64, 'B-JobTitle'), (65, 71, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "aR Olga SORES SAUTDELIGNE  SAUTDELIGNE >>> Mai 202..." with entities "[(43, 51, 'B-DateExp'), (51, 54, 'I-DateExp'), (55...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNELS SAUTDELIGNE  SAUTDELIGNE 2..." with entities "[(311, 321, 'B-JobTitle'), (322, 324, 'I-JobTitle'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "fale a lela aaa ala SAUTDELIGNE  SAUTDELIGNE ASSIS..." with entities "[(45, 55, 'B-JobTitle'), (56, 58, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "RNa hs SAUTDELIGNE  SAUTDELIGNE AOUT 2020 SAUTDELI..." with entities "[(31, 41, 'U-DateExp'), (67, 72, 'B-JobTitle'), (7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 61, 'B-DateExp'), (61, 63, 'I-DateExp'), (63...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE As..." with entities "[(48, 58, 'B-JobTitle'), (58, 61, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 59, 'U-Company'), (82, 95, 'B-JobTitle'), (9...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Juillet 2020-decembre 2020 Gestionnaire Credits en..." with entities "[(0, 12, 'B-DateExp'), (12, 13, 'I-DateExp'), (13,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "mm EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTD..." with entities "[(57, 64, 'B-DateExp'), (65, 67, 'I-DateExp'), (67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "(c) De SAUTDELIGNE Juin 2019 SAUTDELIGNE a SAUTDEL..." with entities "[(19, 28, 'U-DateExp'), (115, 124, 'B-DateExp'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "= EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELI..." with entities "[(1975, 1979, 'B-DateExp'), (1979, 1980, 'I-DateEx...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Depuis juillet 2020 - Assistante technique BTP (Cl..." with entities "[(22, 32, 'B-JobTitle'), (32, 42, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNELLES : SAUTDELIGNE 08 JUIN 20..." with entities "[(542, 555, 'B-DateExp'), (556, 572, 'L-DateExp'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience Professionnelle SAUTDELIGNE  SAUTDELIGN..." with entities "[(51, 63, 'B-JobTitle'), (64, 66, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(61, 69, 'U-DateExp'), (492, 497, 'B-Company'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "ASSISTANTE BACK OFFICE Mai 2019- Juil. 2020 SAUTDE..." with entities "[(0, 10, 'B-JobTitle'), (10, 15, 'I-JobTitle'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(77, 87, 'U-JobTitle'), (89, 102, 'U-JobTitle'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESIONNELLES SAUTDELIGNE  SAUTDELIG..." with entities "[(53, 62, 'B-JobTitle'), (65, 74, 'B-DateExp'), (7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "2016-2019 SAUTDELIGNE  SAUTDELIGNE 2017-2019 SAUTD..." with entities "[(0, 4, 'B-DateExp'), (4, 5, 'I-DateExp'), (5, 9, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 61, 'B-Company'), (62, 67, 'L-Company'), (92...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "olathe oie ice ter SAUTDELIGNE  SAUTDELIGNE De fev..." with entities "[(312, 319, 'B-JobTitle'), (320, 322, 'I-JobTitle'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(54, 65, 'B-JobTitle'), (65, 67, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(53, 63, 'B-DateExp'), (63, 65, 'I-DateExp'), (66...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(53, 64, 'B-JobTitle'), (64, 74, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 57, 'B-DateExp'), (58, 60, 'I-DateExp'), (60...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience SAUTDELIGNE  SAUTDELIGNE Conseillere cl..." with entities "[(36, 47, 'B-JobTitle'), (48, 57, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Assistant conformite detaxe: SAUTDELIGNE  SAUTDELI..." with entities "[(0, 9, 'B-JobTitle'), (10, 20, 'I-JobTitle'), (21...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE Se..." with entities "[(47, 63, 'B-DateExp'), (63, 65, 'I-DateExp'), (66...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "LUI SAUTDELIGNE  SAUTDELIGNE LUI0O- LU 19 SAUTDELI..." with entities "[(142, 152, 'B-JobTitle'), (152, 155, 'I-JobTitle'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences Professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(54, 65, 'B-JobTitle'), (66, 80, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "| SAUTDELIGNE 03/2020 - 10/2020 SAUTDELIGNE ATFPO,..." with entities "[(14, 21, 'B-DateExp'), (22, 23, 'I-DateExp'), (24...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "2019 SAUTDELIGNE  SAUTDELIGNE 2008 / 2019 SAUTDELI..." with entities "[(0, 4, 'U-DateExp'), (30, 34, 'B-DateExp'), (35, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience SAUTDELIGNE  SAUTDELIGNE Alternance con..." with entities "[(36, 46, 'B-JobTitle'), (47, 58, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "2018 SAUTDELIGNE  SAUTDELIGNE 2017 SAUTDELIGNE  SA..." with entities "[(0, 4, 'U-DateExp'), (169, 176, 'B-JobTitle'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE Juin 2020..." with entities "[(41, 50, 'U-DateExp'), (388, 392, 'B-DateExp'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE CH..." with entities "[(1699, 1707, 'L-JobTitle'), (1735, 1745, 'B-Compa...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "= EXPERIENCES SAUTDELIGNE PROFESSIONNELLES SAUTDEL..." with entities "[(67, 78, 'B-JobTitle'), (79, 81, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 55, 'B-Company'), (56, 62, 'I-Company'), (63...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE SAUTDELIGNE  SAUTDELIGNE ASSOCIATION VA..." with entities "[(460, 465, 'B-Company'), (465, 471, 'L-Company'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 65, 'B-DateExp'), (66, 67, 'I-DateExp'), (67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 63, 'B-DateExp'), (63, 65, 'I-DateExp'), (65...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(72, 82, 'B-JobTitle'), (54, 60, 'U-Company'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "it aie Professionnelles SAUTDELIGNE  SAUTDELIGNE o..." with entities "[(56, 65, 'U-Company'), (688, 698, 'B-JobTitle'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE 01..." with entities "[(48, 55, 'B-DateExp'), (56, 58, 'I-DateExp'), (58...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Business Developper- NIT Consult (Croissy S/Seine)..." with entities "[(0, 8, 'B-JobTitle'), (9, 19, 'L-JobTitle'), (21,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "| | Assistante de direction | PRENAX France SAS SA..." with entities "[(17, 27, 'L-JobTitle'), (632, 637, 'I-JobTitle'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE SAUTDELIGNE  SAUTDELIGNE 2020 - 2019 | ..." with entities "[(35, 40, 'B-DateExp'), (41, 42, 'I-DateExp'), (43...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience professionnelle SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 60, 'B-DateExp'), (60, 61, 'I-DateExp'), (61...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Octobre2019 a avril 2020 SAUTDELIGNE  SAUTDELIGNE ..." with entities "[(0, 11, 'B-DateExp'), (11, 13, 'I-DateExp'), (14,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 62, 'B-JobTitle'), (63, 72, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 58, 'U-DateExp'), (312, 317, 'B-JobTitle'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(79, 87, 'B-DateExp'), (88, 99, 'L-DateExp'), (99...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE PROFESSIONNELLES SAUTDELIG..." with entities "[(65, 70, 'B-JobTitle'), (71, 73, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(76, 85, 'B-DateExp'), (85, 87, 'I-DateExp'), (88...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience professionnelle SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 61, 'B-JobTitle'), (62, 64, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Apprenti Ingenieur Thermique en alternance SAUTDEL..." with entities "[(0, 8, 'B-JobTitle'), (8, 18, 'I-JobTitle'), (19,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(51, 56, 'B-DateExp'), (56, 59, 'I-DateExp'), (60...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(56, 68, 'B-DateExp'), (69, 70, 'I-DateExp'), (83...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE DANS LE DOMAINE DE L'ECRIT ET DE LA COR..." with entities "[(83, 92, 'B-DateExp'), (93, 95, 'I-DateExp'), (96...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE BUSINESS DEVE..." with entities "[(37, 45, 'B-JobTitle'), (46, 55, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Fevrier 2019 SAUTDELIGNE  SAUTDELIGNE Septembre 20..." with entities "[(360, 370, 'B-JobTitle'), (371, 373, 'I-JobTitle'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Autres Experiences professionnelles SAUTDELIGNE  S..." with entities "[(259, 264, 'B-DateExp'), (265, 267, 'I-DateExp'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Assistante administrative SAUTDELIGNE  SAUTDELIGNE..." with entities "[(0, 10, 'B-JobTitle'), (11, 25, 'L-JobTitle'), (9...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(57, 69, 'B-DateExp'), (69, 71, 'I-DateExp'), (84...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 64, 'B-JobTitle'), (65, 67, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLE SAUTDELIGNE  SAUTDELIG..." with entities "[(90, 97, 'B-DateExp'), (98, 100, 'I-DateExp'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Juil a Oct 2020 - Agent Administratif polyvalent -..." with entities "[(0, 4, 'B-DateExp'), (4, 6, 'I-DateExp'), (6, 15,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLES SAUTDELIGNE  SAUTDELIG..." with entities "[(53, 62, 'B-DateExp'), (64, 65, 'I-DateExp'), (65...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(54, 64, 'B-JobTitle'), (64, 72, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "i EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDE..." with entities "[(56, 61, 'B-Company'), (62, 68, 'L-Company'), (67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 56, 'U-DateExp'), (357, 363, 'B-JobTitle'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "2020 VTG France SAS, Paris ASSISTANTE COMMERCIAL S..." with entities "[(0, 4, 'U-DateExp'), (4, 8, 'B-Company'), (9, 15,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE Se..." with entities "[(1267, 1277, 'L-DateExp'), (1318, 1329, 'B-JobTit...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "ASSISTANT JURIDIQUE (contrat pro) SAUTDELIGNE  SAU..." with entities "[(0, 10, 'B-JobTitle'), (10, 19, 'L-JobTitle'), (7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE PARADISIA SAU..." with entities "[(37, 46, 'U-Company'), (72, 82, 'B-JobTitle'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Aout -Nov. 2020 SAUTDELIGNE  SAUTDELIGNE Juin 2019..." with entities "[(0, 4, 'B-DateExp'), (4, 6, 'I-DateExp'), (6, 15,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(162, 164, 'I-DateExp'), (164, 168, 'L-DateExp'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONELLE ry SAUTDELIGNE  SAUTDELI..." with entities "[(59, 70, 'B-JobTitle'), (73, 81, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 63, 'U-DateExp'), (76, 86, 'B-JobTitle'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE DANS LE DOMAINE DE LA SAISIE SAUTDELIGN..." with entities "[(65, 75, 'U-DateExp'), (107, 116, 'B-DateExp'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES Po SAUTDELIGNE i SAUTDELIGNE  SAUTDELI..." with entities "[(54, 67, 'B-DateExp'), (67, 68, 'I-DateExp'), (69...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "depuis CONSEILLERE EN GESTION DE PATRIMOINE SAUTDE..." with entities "[(7, 18, 'B-JobTitle'), (19, 21, 'I-JobTitle'), (2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 58, 'B-JobTitle'), (59, 61, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(52, 57, 'U-DateExp'), (57, 69, 'B-JobTitle'), (7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE BUSINESS DEVE..." with entities "[(98, 105, 'B-DateExp'), (105, 107, 'I-DateExp'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE Co..." with entities "[(48, 57, 'B-JobTitle'), (58, 69, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 58, 'B-DateExp'), (59, 61, 'I-DateExp'), (62...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 68, 'B-DateExp'), (75, 86, 'B-JobTitle'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 59, 'U-DateExp'), (114, 120, 'B-Company'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences Professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(54, 64, 'B-JobTitle'), (64, 67, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience professionnelle SAUTDELIGNE  SAUTDELIGN..." with entities "[(93, 100, 'L-Company'), (721, 728, 'I-JobTitle'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experience professionnelle SAUTDELIGNE  SAUTDELIGN..." with entities "[(54, 64, 'B-DateExp'), (64, 67, 'I-DateExp'), (67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "8 EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDE..." with entities "[(56, 63, 'B-DateExp'), (63, 67, 'I-DateExp'), (67...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 61, 'B-DateExp'), (62, 63, 'I-DateExp'), (75...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "OFFICE MANAGER POLE COMMUNICATION SAUTDELIGNE  SAU..." with entities "[(0, 7, 'B-JobTitle'), (7, 14, 'L-JobTitle'), (84,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE AC..." with entities "[(48, 57, 'B-JobTitle'), (58, 60, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLES SAUTDELIGNE  SAUTDELIG..." with entities "[(269, 271, 'B-Company'), (271, 278, 'I-Company'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE aa : annie an..." with entities "[(460, 470, 'U-JobTitle'), (470, 479, 'B-DateExp')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 61, 'B-DateExp'), (61, 63, 'I-DateExp'), (76...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(81, 92, 'B-Company'), (93, 104, 'I-Company'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "- erlences professionnelles SAUTDELIGNE  SAUTDELIG..." with entities "[(67, 77, 'B-JobTitle'), (78, 80, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 65, 'B-JobTitle'), (66, 68, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Assistant copropriete 09/2018 - ace jour SAUTDELIG..." with entities "[(0, 10, 'B-JobTitle'), (10, 21, 'L-JobTitle'), (2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE SAUTDELIGNE  SAUTDELIGNE   SAUTDELIGNE ..." with entities "[(63, 73, 'B-JobTitle'), (74, 76, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDELIGN..." with entities "[(86, 98, 'U-DateExp'), (100, 107, 'B-Company'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "CDI Catenon Sarl |Deeecembre 2019 - Aujourd' hui S..." with entities "[(4, 11, 'U-Company'), (18, 33, 'U-DateExp'), (194...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Juillet 2012 SAUTDELIGNE a nov 2019 SAUTDELIGNE  S..." with entities "[(0, 12, 'B-DateExp'), (25, 26, 'I-DateExp'), (26,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(360, 371, 'U-Company'), (393, 404, 'B-JobTitle')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 62, 'B-DateExp'), (62, 64, 'I-DateExp'), (65...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "WA aa ana SAUTDELIGNE  SAUTDELIGNE MANAGER OPERATI..." with entities "[(35, 42, 'B-JobTitle'), (43, 55, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Technicien --Administrateur de proximite SAUTDELIG..." with entities "[(0, 10, 'B-JobTitle'), (13, 27, 'I-JobTitle'), (2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "2019 -- 2020 SAUTDELIGNE  SAUTDELIGNE 2018 - 2019 ..." with entities "[(0, 4, 'B-DateExp'), (4, 7, 'I-DateExp'), (8, 12,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE NEOTISS (..." with entities "[(41, 48, 'U-Company'), (89, 98, 'B-DateExp'), (99...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES : SAUTDELIGNE  SAUTDE..." with entities "[(56, 64, 'B-Company'), (64, 73, 'L-Company'), (13...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Mars SAUTDELIGNE 2019 SAUTDELIGNE  SAUTDELIGNE WED..." with entities "[(391, 400, 'U-JobTitle'), (401, 404, 'B-Company')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "By isqacieness SAUTDELIGNE  SAUTDELIGNE   SAUTDELI..." with entities "[(132, 141, 'U-Company'), (67, 76, 'B-DateExp'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES ADDITIONNELLES SAUTDELIGNE  SAUTDELIGN..." with entities "[(51, 63, 'B-JobTitle'), (63, 73, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "" SAUTDELIGNE  SAUTDELIGNE TS SAUTDELIGNE 18 Sept ..." with entities "[(42, 53, 'B-DateExp'), (65, 74, 'L-DateExp'), (13...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLLES SAUTDELIGNE  SAUTDEL..." with entities "[(62, 70, 'U-DateExp'), (73, 84, 'B-JobTitle'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 64, 'B-JobTitle'), (65, 71, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "= oe OO = SAUTDELIGNE PROFESSIONNELLES SAUTDELIGNE..." with entities "[(64, 78, 'B-JobTitle'), (78, 83, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Aout 2018 SAUTDELIGNE Juillet 2020 SAUTDELIGNE  SA..." with entities "[(0, 9, 'B-DateExp'), (22, 34, 'L-DateExp'), (59, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE PROFESSIONNELLES SAUTDELIG..." with entities "[(66, 70, 'B-DateExp'), (70, 71, 'I-DateExp'), (71...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE Agent Service..." with entities "[(37, 42, 'B-JobTitle'), (43, 50, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 58, 'B-Company'), (58, 66, 'L-Company'), (94...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Experiences professionnelles SAUTDELIGNE  SAUTDELI..." with entities "[(139, 146, 'B-JobTitle'), (147, 149, 'I-JobTitle'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(54, 66, 'B-JobTitle'), (66, 80, 'L-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(81, 85, 'B-JobTitle'), (86, 88, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES SAUTDELIGNE  SAUTDELIGNE Paris SAUTDEL..." with entities "[(55, 68, 'B-DateExp'), (68, 70, 'I-DateExp'), (70...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELI..." with entities "[(83, 91, 'B-JobTitle'), (92, 94, 'I-JobTitle'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Du 01/2019 SAUTDELIGNE au 04/2019 SAUTDELIGNE  SAU..." with entities "[(256, 265, 'L-JobTitle'), (147, 155, 'L-DateExp')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "(c) EXPERIENCE PROFESSIONNELLE SAUTDELIGNE  SAUTDE..." with entities "[(56, 60, 'U-DateExp'), (78, 85, 'B-JobTitle'), (8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "PARCOURS PROFESSIONNEL SAUTDELIGNE  SAUTDELIGNE   ..." with entities "[(75, 83, 'U-Company'), (99, 110, 'B-DateExp'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "EXPERIENCES PROFESSIONNELLES | SAUTDELIGNE  SAUTDE..." with entities "[(56, 64, 'B-Company'), (64, 76, 'I-Company'), (76...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/remyadda/.pyenv/versions/3.9.0/lib/python3.9/site-packages/spacy/training/iob_utils.py:139: UserWarning: [W030] Some entities could not be aligned in the text "Parcours professionnel SAUTDELIGNE  SAUTDELIGNE 05..." with entities "[(48, 53, 'B-DateExp'), (53, 59, 'L-DateExp'), (59...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %% [markdown]
# ### Save a model

# %%
def save_model(nlp, output_dir, model_name):
    """Input: nlp (model), directory ou l'on souhaite save le mpdel,
    model_name est le nom qu'on souhaite donner a notre modele"""
    # Save model 
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.meta['name'] = model_name  # rename model
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

save_model(nlp, "/Users/remyadda/Desktop/AD/Projets/ALFRED/ALFRED_PROJECT/Model_NER_3/Modeles", 'ner')
# Out:
# Saved model to /Users/remyadda/Desktop/AD/Projets/ALFRED/ALFRED_PROJECT/Model_NER_3/Modeles

# %% [markdown]
# ### Test on new datas

# %%
def test_ner_model(output_dir, test_text):
    """Permet de tester un NER
    Input: directory du modele et texte a tester ainsi que le texte
    Output: Renvoie les labels predits ainsi que le texte correspondant a chaque label"""
    # Test the saved model
    nlp = spacy.load(output_dir)
    doc = nlp(test_text)
    predicted_labels = []
    corresponding_text = []
    for ent in doc.ents:
        predicted_labels.append(ent.label_)
        corresponding_text.append(ent.text)
    return predicted_labels, corresponding_text

# %%
TEST[0]
# Out:
# ("Experience SAUTDELIGNE  SAUTDELIGNE Acheteuse SAUTDELIGNE CREDIT AGRICOLE LEASING & FACTORING - Montrouge (92) SAUTDELIGNE novembre 2018 - aout 2020 SAUTDELIGNE  SAUTDELIGNE C/ Outil achats (IVALUA) SAUTDELIGNE  SAUTDELIGNE C/<< Reporting SAUTDELIGNE  SAUTDELIGNE C/e Appels d'Offres SAUTDELIGNE  SAUTDELIGNE e Plenieres achats SAUTDELIGNE  SAUTDELIGNE C/<< Negociation des contrats SAUTDELIGNE  SAUTDELIGNE Chef de projet SAUTDELIGNE PRESTIGE AVENUE - Paris 8e (75) SAUTDELIGNE mars 2018 - aout 2018",
#  {'entities': [(36, 45, 'U-JobTitle'),
#    (57, 64, 'B-Company'),
#    (65, 73, 'I-Company'),
#    (74, 81, 'I-Company'),
#    (82, 83, 'I-Company'),
#    (84, 93, 'L-Company'),
#    (123, 136, 'B-DateExp'),
#    (137, 138, 'I-DateExp'),
#    (138, 148, 'L-DateExp'),
#    (408, 413, 'B-JobTitle'),
#    (413, 415, 'I-JobTitle'),
#    (416, 422, 'L-JobTitle'),
#    (435, 443, 'B-Company'),
#    (444, 450, 'L-Company'),
#    (479, 488, 'B-DateExp'),
#    (489, 491, 'I-DateExp'),
#    (491, 500, 'L-DateExp')]})

# %%
def retrieve_trueLabelAndWord(DATASET):
    """Permet de recuperer deux listes: True label, et le word correspondant
    Ceci permettra de comparer les valeurs reelles aux valeurs predites du NER"""
    true_labels = []
    corresponding_text = []
    for element in DATASET:
        # on retrieve le texte
        text = element[0]
        label = element[1]
        label = label['entities']
        for e in label:
            start = e[0]
            end = e[1]
            target = e[2]
            true_labels.append(target)
            corresponding_word = text[start:end]
            corresponding_text.append(corresponding_word)
    return true_labels, corresponding_text

# %%
def X_test(DATASET):
    """Permet de recuperer le texte afin d'effectuer les predictions"""
    texts = []
    for element in DATASET:
        text = element[0]
        texts.append(text)
    return texts

# %%
Xtest = X_test(TEST)
print(Xtest[0])
# Out:
# EXPERIENCES PROFESSIONNELLES SAUTDELIGNE  SAUTDELIGNE Collaborateur Caisse SAUTDELIGNE  SAUTDELIGNE Chanel SAUTDELIGNE  SAUTDELIGNE 2018 & 2020, Paris SAUTDELIGNE  SAUTDELIGNE = Accompagnement du client dans son parcours d'achat SAUTDELIGNE =" Ventes additionnelles d'articles en caisse SAUTDELIGNE  SAUTDELIGNE Agent de maitrise Caisses & CRM SAUTDELIGNE  SAUTDELIGNE Prada SAUTDELIGNE  SAUTDELIGNE yA Os EA 0N Re rela SAUTDELIGNE  SAUTDELIGNE = Responsable des flux de caisse et des services SAUTDELIGNE generaux de la boutique (fournitures, contrats de SAUTDELIGNE maintenance, entretien, uniformes, R.H.) SAUTDELIGNE  SAUTDELIGNE =" Enrichissements des donnees CRM SAUTDELIGNE  SAUTDELIGNE = Management en boutique SAUTDELIGNE  SAUTDELIGNE Collaborateur Caisse SAUTDELIGNE  SAUTDELIGNE Gucci Montaigne SAUTDELIGNE  SAUTDELIGNE yA ON TC SAUTDELIGNE  SAUTDELIGNE =" Creation d'outils de pilotage (Tableaux Excel) SAUTDELIGNE  SAUTDELIGNE Conseiller Vendeur & SAV SAUTDELIGNE  SAUTDELIGNE aA ULI SAUTDELIGNE  SAUTDELIGNE yA0h Rey eT aC SAUTDELIGNE  SAUTDELIGNE = Chiffre d'affaires personnel de 350KEEUR (28,4% C.A) SAUTDELIGNE  SAUTDELIGNE Conseiller Vendeur SAUTDELIGNE  SAUTDELIGNE Louis Vuitton (en apprentissage) SAUTDELIGNE  SAUTDELIGNE 2008-2011, Paris SAUTDELIGNE  SAUTDELIGNE =" Responsable accessoires homme, editions. SAUTDELIGNE  SAUTDELIGNE = Animation et creation de reunions & formations. SAUTDELIGNE  SAUTDELIGNE = Projet personnel : Introduction du developpement SAUTDELIGNE durable.

# %% [markdown]
# #### 1- Récupération des tokens et labels que le modèle devrait être capable de prédire (True tuples on les appelera)

# %%
true_labels, true_corresponding_words = retrieve_trueLabelAndWord(TEST)
print('True labels : ', true_labels[0], ' --> True corresponding word : ',true_corresponding_words[0])
# Create list of tuples (word, label_predicted) --> useful for metrics

def make_tuples(true_token, true_labels):
    """Input: la liste de mots (token) ainsi que la liste de labels correspondante
       Output: liste de tuples ou chaque tuple est de la forme (token, label)"""
    true_tuple = []
    for w, p in zip(true_token, true_labels):
        true_tuple.append((w, p))

    print(len(true_tuple), 'tuples')
    return true_tuple

# Nbe de tuples a trouver
true_tuple = make_tuples(true_corresponding_words, true_labels)
# Out:
# True labels :  B-JobTitle  --> True corresponding word :  Collaborateur
# 8890 tuples

# %% [markdown]
# ### Predictions

# %%
# On predit chaque texte de Xtest
output_dir = "/Users/remyadda/Desktop/AD/Projets/ALFRED/ALFRED_PROJECT/Model_NER_3"
preds = []
predicted_corresponding_word_list = []
for text in Xtest:
    predictions, predicted_corresponding_word = test_ner_model(output_dir, text)
    preds.extend(predictions)
    predicted_corresponding_word_list.extend(predicted_corresponding_word)

# %% [markdown]
# #### 2 - Récupération des tokens et labels que le modèle a prédit (predicted tuples on les appelera)

# %%
# Create list of tuples (word, label_predicted) --> useful for metrics
# Nbe de tuples prédits
predicted_tuple = make_tuples(predicted_corresponding_word_list, preds)
# Out:
# 1507 tuples

# %% [markdown]
# ### Defintion des Metrics

# %%
# Explication : supposons que dans le Test set il y ait 200 mots a labeliser, et que le modele en trouve 100, 
# alors, le coverage serait de 50%. Certes toutes les predictions peuvent etre bonnes, mais il en manque la moitié.
def get_metrics(y_pred, y_true):
    """Input: y_pred et y_true sous forme de listes de tuple (texte, label)
    Renvoie le poucentage de bons tuples (texte, label) détectés par le modele"""
    y_true_copy = y_true.copy()
    y_pred_copy = y_pred.copy()
    wrong_tuples = []
    good_tuples = []
    count = 0
    for tuple_ in y_pred_copy:
        count += 1
        if tuple_ in y_true_copy:
            y_true_copy.remove(tuple_)
            good_tuples.append(tuple_)
        else:
            # tuple qui na pas lieu d'exister
            wrong_tuples.append(tuple_)
    #print(count)
    accuracy_1 = np.round(len(good_tuples)/len(y_pred), 3) # cb de bonnes predictions par rap a ce que je predis
    accuracy_2 = np.round(len(good_tuples)/len(y_true), 3) # % cb de bonnes predictions par rap a ce quil fallait trouver
    
    #lets take a look on bad predictions
    # erreur de type 1 : mot trouvé, mais prédiction fausse
    label_error = {} # on spotera les labels où le modèle fait erreur
    count_error_I = 0
    for tuple_ in wrong_tuples:
        for TrueTuple in y_true_copy:
            if tuple_[0] == TrueTuple[0]:
                count_error_I += 1
                if (tuple_[1], TrueTuple[1]) not in label_error:
                    label_error[(tuple_[1], TrueTuple[1])] = 1
                else:
                    label_error[(tuple_[1], TrueTuple[1])] += 1
                y_true_copy.remove(TrueTuple)
                break
        # Si c'est pas une erreur de type I c'est qu'il s'agit d'une erreur de type II 
        # cad un mot releve qui n'aurait jamais du l'etre
    count_error_II = len(wrong_tuples) - count_error_I
    coverage = np.round(len(y_true) / len(y_pred) * 100, 1)
    coverage = np.round(np.abs(100 - coverage), 1)
    print("Nombre de mots à prédire pour l'ensemble du test set : ", len(y_true))
    print("Nombre de mots prédits par le NER pour l'ensemble du test set : ", len(y_pred))
    print('Coverage : ', coverage, '% de difference')
    print('----------------------------------------------------------------------')
    print(len(good_tuples), ' mots ont bien été relevés ET prédits par le NER')
    print(len(wrong_tuples), " mots ont mal été prédits (erreur de type I ou type II)")
    print('Bonnes prédictions + Mauvaises prédictions =', len(good_tuples)+len(wrong_tuples))
    print('----------------------------------------------------------------------')
    print('Accuracy I (bonne pred / total pred) : ', accuracy_1*100, ' %')
    print('Accuracy II (bonne pred / total expected pred) : ', accuracy_2*100, ' %')
    print('----------------------------------------------------------------------')
    print('Nbe erreur type I : ', count_error_I, ' (mots bien relevés mais mal prédits)')
    print('Nbe erreur type II : ', count_error_II, " (mots qui n'auraient pas du être prédits)")
    print('----------------------------------------------------------------------')
    print("Confusions faites par l'algo (prediction, true_label): \n", label_error)

# %% [markdown]
# #### Lets check our results

# %%
get_metrics(predicted_tuple, true_tuple)
# Out:
# Nombre de mots à prédire pour l'ensemble du test set :  1772
# Nombre de mots prédits par le NER pour l'ensemble du test set :  1507
# Coverage :  17.6 % de difference
# ----------------------------------------------------------------------
# 852  mots ont bien été relevés ET prédits par le NER
# 655  mots ont mal été prédits (erreur de type I ou type II)
# Bonnes prédictions + Mauvaises prédictions = 1507
# ----------------------------------------------------------------------
# Accuracy I (bonne pred / total pred) :  56.49999999999999  %
# Accuracy II (bonne pred / total expected pred) :  48.1  %
# ----------------------------------------------------------------------
# Nbe erreur type I :  95  (mots bien relevés mais mal prédits)
# Nbe erreur type II :  560  (mots qui n'auraient pas du être prédits)
# ----------------------------------------------------------------------
# Confusions faites par l'algo (prediction, true_label):
#  {('L-JobTitle', 'I-JobTitle'): 13, ('B-JobTitle', 'I-JobTitle'): 2, ('L-Company', 'I-Company'): 5, ('B-JobTitle', 'B-Company'): 5, ('L-JobTitle', 'L-Company'): 7, ('U-JobTitle', 'I-JobTitle'): 1, ('I-Company', 'B-Company'): 3, ('I-Company', 'B-JobTitle'): 1, ('I-JobTitle', 'L-JobTitle'): 7, ('L-Company', 'U-Company'): 3, ('L-DateExp', 'U-DateExp'): 4, ('B-JobTitle', 'U-JobTitle'): 2, ('L-JobTitle', 'U-Company'): 2, ('B-Company', 'U-Company'): 3, ('U-DateExp', 'L-DateExp'): 1, ('L-Company', 'B-Company'): 2, ('I-JobTitle', 'B-JobTitle'): 1, ('I-DateExp', 'I-JobTitle'): 7, ('B-JobTitle', 'L-JobTitle'): 1, ('L-DateExp', 'I-DateExp'): 2, ('L-Company', 'L-JobTitle'): 1, ('U-Company', 'I-JobTitle'): 1, ('I-Company', 'I-JobTitle'): 1, ('I-Company', 'L-Company'): 2, ('U-Company', 'B-Company'): 2, ('U-JobTitle', 'I-Company'): 1, ('L-Company', 'B-JobTitle'): 1, ('B-DateExp', 'U-DateExp'): 1, ('L-JobTitle', 'I-Company'): 1, ('U-DateExp', 'B-Company'): 1, ('U-Company', 'U-JobTitle'): 1, ('I-DateExp', 'I-Company'): 4, ('B-Company', 'B-DateExp'): 1, ('B-Company', 'U-JobTitle'): 1, ('I-JobTitle', 'B-Company'): 1, ('L-JobTitle', 'B-Company'): 1, ('I-JobTitle', 'I-Company'): 1, ('L-JobTitle', 'L-DateExp'): 1}

# %% [markdown]
# #### Pour appliquer cette fonction metric, il faut d'abord diviser votre DATASET en TRAIN et TEST.
#     Puis, dans le cas ou votre NER prend ceci en INPUT :
#
#     INPUT :
#     ('LOGICIELS MAITRISES: WORD -- EXCEL -- SAGE -- POWERPOINT -- OUTLOOK',
#      {'entities': [(21, 25, 'U-SKILLS'),
#        (29, 34, 'U-SKILLS'),
#        (38, 42, 'U-SKILLS'),
#        (46, 56, 'U-SKILLS'),
#        (60, 67, 'U-SKILLS')]}),
#
#     entrainez votre NER sur le train set.
#
#     Afin de tester ses performances sur le test, recuperer les mots ainsi que les preditions qu'il aurait du       pouvoir effectuer dans le meilleur des cas, pour cela, utilisez la fonction "retrieve_trueLabelAndWord" qui prend en input l'INPUT ci dessus, et renvoie deux listes : true label et mots à predire.
#
#         Utiliser ensuite la fonction "make_tuple" afin de merge ces deux listes en une seule liste de tuples.
#         On utilise deux fois cette fonction :
#         - pour les reels labels a trouver
#         - pour les prediction effectuées par l'algo
#
#         Enfin on applique la fonction get_metrics
